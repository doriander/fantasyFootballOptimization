# %% [markdown]
# ### Project

# %%
import urllib, json
import pandas as pd
import re
from itertools import permutations
from pulp import *

# %%
# Reading the Fantasy Football Salary and Projection
dataset = pd.read_csv("fantasy_football_salary_and_projection_w10.csv", header = 0)
print(dataset.shape)
dataset.head(10)
# Out:
# (300, 10)
#    Rank                  Name Team Position  Week Opponent  \
# 0   106         Chicago Bears  CHI      DST    11      MIN
# 1   123   Pittsburgh Steelers  PIT      DST    11      JAX
# 2   131      Baltimore Ravens  BAL      DST    11      CIN
# 3   131     Arizona Cardinals  ARI      DST    11      OAK
# 4   149     Carolina Panthers  CAR      DST    11      DET
# 5   149   Washington Redskins  WAS      DST    11      HOU
# 6   152  Los Angeles Chargers  LAC      DST    11      DEN
# 7   157      Seattle Seahawks  SEA      DST    11       GB
# 8   157       Atlanta Falcons  ATL      DST    11      DAL
# 9   157     Minnesota Vikings  MIN      DST    11      CHI
#
#    UpcomingOpponentRank  UpcomingOpponentPositionRank  FanDuelSalary  \
# 0                   NaN                           NaN           4700
# 1                   NaN                           NaN           3800
# 2                   NaN                           NaN           4200
# 3                   NaN                           NaN           4000
# 4                   NaN                           NaN           4000
# 5                   NaN                           NaN           3600
# 6                   NaN                           NaN           4600
# 7                   NaN                           NaN           3100
# 8                   NaN                           NaN           3500
# 9                   NaN                           NaN           3800
#
#    FantasyPointsFanDuel
# 0                   8.6
# 1                   8.2
# 2                   8.0
# 3                   8.0
# 4                   7.3
# 5                   7.3
# 6                   7.2
# 7                   6.7
# 8                   6.7
# 9                   6.7

# %%
# Drop columns that won't be used 
dataset = dataset.drop(['Team', 'Week', 'Opponent', 'UpcomingOpponentRank', 'UpcomingOpponentPositionRank'], axis = 1)
dataset.head(10)
# Out:
#    Rank                  Name Position  FanDuelSalary  FantasyPointsFanDuel
# 0   106         Chicago Bears      DST           4700                   8.6
# 1   123   Pittsburgh Steelers      DST           3800                   8.2
# 2   131      Baltimore Ravens      DST           4200                   8.0
# 3   131     Arizona Cardinals      DST           4000                   8.0
# 4   149     Carolina Panthers      DST           4000                   7.3
# 5   149   Washington Redskins      DST           3600                   7.3
# 6   152  Los Angeles Chargers      DST           4600                   7.2
# 7   157      Seattle Seahawks      DST           3100                   6.7
# 8   157       Atlanta Falcons      DST           3500                   6.7
# 9   157     Minnesota Vikings      DST           3800                   6.7

# %%
# Add flex position
flex = dataset[dataset.Position.isin(["RB","WR","TE"])].copy()
flex.Position = "FLEX"
dataset = pd.concat([dataset, flex])
dataset = dataset.drop('Rank', axis=1)

dataset.head()
# Out:
#                   Name Position  FanDuelSalary  FantasyPointsFanDuel
# 0        Chicago Bears      DST           4700                   8.6
# 1  Pittsburgh Steelers      DST           3800                   8.2
# 2     Baltimore Ravens      DST           4200                   8.0
# 3    Arizona Cardinals      DST           4000                   8.0
# 4    Carolina Panthers      DST           4000                   7.3

# %%
#dataset = dataset.reset_index()
dataset[dataset.Position=="QB"].head(15)

salaries = {}
points = {}
for pos in dataset.Position.unique():
    available_pos = dataset[dataset.Position == pos]
    salary = list(available_pos[["Name","FanDuelSalary"]].set_index("Name").to_dict().values())[0]
    point = list(available_pos[["Name","FantasyPointsFanDuel"]].set_index("Name").to_dict().values())[0]
    salaries[pos] = salary
    points[pos] = point

pos_num_available = {
    "QB": 1,
    "RB": 2,
    "WR": 2,
    "TE": 1,
    "DST": 1,
    "K": 1,
    "FLEX": 1
}

# %%
SALARY_CAP = 50000
_vars = {k: LpVariable.dict(k, v, cat="Binary") for k, v in points.items()}
_vars
# Out:
# {'DST': {'Chicago Bears': DST_Chicago_Bears,
#   'Pittsburgh Steelers': DST_Pittsburgh_Steelers,
#   'Baltimore Ravens': DST_Baltimore_Ravens,
#   'Arizona Cardinals': DST_Arizona_Cardinals,
#   'Carolina Panthers': DST_Carolina_Panthers,
#   'Washington Redskins': DST_Washington_Redskins,
#   'Los Angeles Chargers': DST_Los_Angeles_Chargers,
#   'Seattle Seahawks': DST_Seattle_Seahawks,
#   'Atlanta Falcons': DST_Atlanta_Falcons,
#   'Minnesota Vikings': DST_Minnesota_Vikings,
#   'New Orleans Saints': DST_New_Orleans_Saints,
#   'Houston Texans': DST_Houston_Texans,
#   'Green Bay Packers': DST_Green_Bay_Packers,
#   'New York Giants': DST_New_York_Giants,
#   'Oakland Raiders': DST_Oakland_Raiders,
#   'Indianapolis Colts': DST_Indianapolis_Colts,
#   'Jacksonville Jaguars': DST_Jacksonville_Jaguars,
#   'Detroit Lions': DST_Detroit_Lions,
#   'Tampa Bay Buccaneers': DST_Tampa_Bay_Buccaneers,
#   'Tennessee Titans': DST_Tennessee_Titans,
#   'Kansas City Chiefs': DST_Kansas_City_Chiefs,
#   'Cincinnati Bengals': DST_Cincinnati_Bengals,
#   'Dallas Cowboys': DST_Dallas_Cowboys,
#   'Los Angeles Rams': DST_Los_Angeles_Rams,
#   'Denver Broncos': DST_Denver_Broncos,
#   'Philadelphia Eagles': DST_Philadelphia_Eagles},
#  'K': {'Wil Lutz': K_Wil_Lutz,
#   'Greg Zuerlein': K_Greg_Zuerlein,
#   'Harrison Butker': K_Harrison_Butker,
#   'Justin Tucker': K_Justin_Tucker,
#   'Graham Gano': K_Graham_Gano,
#   'Michael Badgley': K_Michael_Badgley,
#   'Adam Vinatieri': K_Adam_Vinatieri,
#   'Matt Bryant': K_Matt_Bryant,
#   'Sebastian Janikowski': K_Sebastian_Janikowski,
#   'Ryan Succop': K_Ryan_Succop,
#   'Matt Prater': K_Matt_Prater,
#   'Jake Elliott': K_Jake_Elliott,
#   'Aldrick Rosas': K_Aldrick_Rosas,
#   "Ka'imi Fairbairn": K_Ka'imi_Fairbairn,
#   'Brett Maher': K_Brett_Maher,
#   'Chris Boswell': K_Chris_Boswell,
#   'Josh Lambo': K_Josh_Lambo,
#   'Cody Parkey': K_Cody_Parkey,
#   'Mason Crosby': K_Mason_Crosby,
#   'Dustin Hopkins': K_Dustin_Hopkins,
#   'Brandon McManus': K_Brandon_McManus,
#   'Dan Bailey': K_Dan_Bailey,
#   'Randy Bullock': K_Randy_Bullock,
#   'Matthew McCrane': K_Matthew_McCrane,
#   'Daniel Carlson': K_Daniel_Carlson},
#  'QB': {'Patrick Mahomes': QB_Patrick_Mahomes,
#   'Cam Newton': QB_Cam_Newton,
#   'Jared Goff': QB_Jared_Goff,
#   'Carson Wentz': QB_Carson_Wentz,
#   'Drew Brees': QB_Drew_Brees,
#   'Aaron Rodgers': QB_Aaron_Rodgers,
#   'Matt Ryan': QB_Matt_Ryan,
#   'Ryan Fitzpatrick': QB_Ryan_Fitzpatrick,
#   'Russell Wilson': QB_Russell_Wilson,
#   'Andrew Luck': QB_Andrew_Luck,
#   'Ben Roethlisberger': QB_Ben_Roethlisberger,
#   'Mitch Trubisky': QB_Mitch_Trubisky,
#   'Marcus Mariota': QB_Marcus_Mariota,
#   'Deshaun Watson': QB_Deshaun_Watson,
#   'Dak Prescott': QB_Dak_Prescott,
#   'Philip Rivers': QB_Philip_Rivers,
#   'Matthew Stafford': QB_Matthew_Stafford,
#   'Kirk Cousins': QB_Kirk_Cousins,
#   'Eli Manning': QB_Eli_Manning,
#   'Blake Bortles': QB_Blake_Bortles,
#   'Lamar Jackson': QB_Lamar_Jackson,
#   'Case Keenum': QB_Case_Keenum,
#   'Alex Smith': QB_Alex_Smith,
#   'Derek Carr': QB_Derek_Carr,
#   'Josh Rosen': QB_Josh_Rosen,
#   'Andy Dalton': QB_Andy_Dalton,
#   'Robert Griffin III': QB_Robert_Griffin_III,
#   'Taysom Hill': QB_Taysom_Hill,
#   'Jameis Winston': QB_Jameis_Winston},
#  'RB': {'Todd Gurley': RB_Todd_Gurley,
#   'Saquon Barkley': RB_Saquon_Barkley,
#   'Alvin Kamara': RB_Alvin_Kamara,
#   'Melvin Gordon': RB_Melvin_Gordon,
#   'Ezekiel Elliott': RB_Ezekiel_Elliott,
#   'Kareem Hunt': RB_Kareem_Hunt,
#   'Christian McCaffrey': RB_Christian_McCaffrey,
#   'David Johnson': RB_David_Johnson,
#   'James Conner': RB_James_Conner,
#   'Leonard Fournette': RB_Leonard_Fournette,
#   'Aaron Jones': RB_Aaron_Jones,
#   'Joe Mixon': RB_Joe_Mixon,
#   'Kerryon Johnson': RB_Kerryon_Johnson,
#   'Tevin Coleman': RB_Tevin_Coleman,
#   'Dion Lewis': RB_Dion_Lewis,
#   'Marlon Mack': RB_Marlon_Mack,
#   'Dalvin Cook': RB_Dalvin_Cook,
#   'Phillip Lindsay': RB_Phillip_Lindsay,
#   'Mark Ingram': RB_Mark_Ingram,
#   'Alex Collins': RB_Alex_Collins,
#   'Lamar Miller': RB_Lamar_Miller,
#   'Tarik Cohen': RB_Tarik_Cohen,
#   'Adrian Peterson': RB_Adrian_Peterson,
#   'Chris Carson': RB_Chris_Carson,
#   'Doug Martin': RB_Doug_Martin,
#   'Jordan Howard': RB_Jordan_Howard,
#   'Peyton Barber': RB_Peyton_Barber,
#   'Mike Davis': RB_Mike_Davis,
#   'Theo Riddick': RB_Theo_Riddick,
#   'Ito Smith': RB_Ito_Smith,
#   'Jalen Richard': RB_Jalen_Richard,
#   'Derrick Henry': RB_Derrick_Henry,
#   'TJ Yeldon': RB_TJ_Yeldon,
#   'Royce Freeman': RB_Royce_Freeman,
#   'Nyheim Hines': RB_Nyheim_Hines,
#   'Austin Ekeler': RB_Austin_Ekeler,
#   'Wendell Smallwood': RB_Wendell_Smallwood,
#   'Josh Adams': RB_Josh_Adams,
#   'Giovani Bernard': RB_Giovani_Bernard,
#   'Kapri Bibbs': RB_Kapri_Bibbs,
#   'Javorius Allen': RB_Javorius_Allen,
#   'Rashaad Penny': RB_Rashaad_Penny,
#   'Latavius Murray': RB_Latavius_Murray,
#   'Corey Clement': RB_Corey_Clement,
#   'Alfred Blue': RB_Alfred_Blue,
#   'Jacquizz Rodgers': RB_Jacquizz_Rodgers,
#   'Spencer Ware': RB_Spencer_Ware,
#   'Jamaal Williams': RB_Jamaal_Williams,
#   'Devontae Booker': RB_Devontae_Booker,
#   'Malcolm Brown': RB_Malcolm_Brown,
#   'LeGarrette Blount': RB_LeGarrette_Blount,
#   'Ty Montgomery': RB_Ty_Montgomery,
#   'Chase Edmonds': RB_Chase_Edmonds,
#   'Wayne Gallman': RB_Wayne_Gallman,
#   'Jaylen Samuels': RB_Jaylen_Samuels,
#   'Cameron Artis-Payne': RB_Cameron_Artis_Payne,
#   'Jordan Wilkins': RB_Jordan_Wilkins,
#   'Carlos Hyde': RB_Carlos_Hyde,
#   'Deandre Washington': RB_Deandre_Washington,
#   'Gus Edwards': RB_Gus_Edwards,
#   'Rod Smith': RB_Rod_Smith,
#   'Elijhaa Penny': RB_Elijhaa_Penny},
#  'TE': {'Travis Kelce': TE_Travis_Kelce,
#   'Zach Ertz': TE_Zach_Ertz,
#   'Greg Olsen': TE_Greg_Olsen,
#   'OJ Howard': TE_OJ_Howard,
#   'Trey Burton': TE_Trey_Burton,
#   'Jordan Reed': TE_Jordan_Reed,
#   'Eric Ebron': TE_Eric_Ebron,
#   'Jared Cook': TE_Jared_Cook,
#   'Austin Hooper': TE_Austin_Hooper,
#   'Evan Engram': TE_Evan_Engram,
#   'Jack Doyle': TE_Jack_Doyle,
#   'Vance McDonald': TE_Vance_McDonald,
#   'Jimmy Graham': TE_Jimmy_Graham,
#   'Kyle Rudolph': TE_Kyle_Rudolph,
#   'Ricky Seals-Jones': TE_Ricky_Seals_Jones,
#   'Jeff Heuerman': TE_Jeff_Heuerman,
#   'CJ Uzomah': TE_CJ_Uzomah,
#   'Benjamin Watson': TE_Benjamin_Watson,
#   'Nick Vannett': TE_Nick_Vannett,
#   "James O'Shaughnessy": TE_James_O'Shaughnessy,
#   'Jonnu Smith': TE_Jonnu_Smith,
#   'Mark Andrews': TE_Mark_Andrews,
#   'Geoff Swaim': TE_Geoff_Swaim,
#   'Jesse James': TE_Jesse_James,
#   'Gerald Everett': TE_Gerald_Everett,
#   'Luke Willson': TE_Luke_Willson,
#   'Tyler Higbee': TE_Tyler_Higbee,
#   'Vernon Davis': TE_Vernon_Davis,
#   'Cameron Brate': TE_Cameron_Brate,
#   'Dallas Goedert': TE_Dallas_Goedert,
#   'Ryan Griffin': TE_Ryan_Griffin,
#   'Antonio Gates': TE_Antonio_Gates,
#   'Hayden Hurst': TE_Hayden_Hurst,
#   'Mo Alie-Cox': TE_Mo_Alie_Cox,
#   'Virgil Green': TE_Virgil_Green,
#   'Jordan Thomas': TE_Jordan_Thomas,
#   'Lance Kendricks': TE_Lance_Kendricks,
#   'Ed Dickson': TE_Ed_Dickson,
#   'Rhett Ellison': TE_Rhett_Ellison,
#   'Josh Hill': TE_Josh_Hill,
#   'Adam Shaheen': TE_Adam_Shaheen,
#   'Demetrius Harris': TE_Demetrius_Harris,
#   'Nick Boyle': TE_Nick_Boyle,
#   'Blake Bell': TE_Blake_Bell,
#   'Luke Stocker': TE_Luke_Stocker,
#   'Levine Toilolo': TE_Levine_Toilolo,
#   'Jordan Akins': TE_Jordan_Akins,
#   'Matt LaCosse': TE_Matt_LaCosse,
#   'Jermaine Gresham': TE_Jermaine_Gresham,
#   'Jordan Franks': TE_Jordan_Franks,
#   'Dalton Schultz': TE_Dalton_Schultz,
#   'Dan Arnold': TE_Dan_Arnold},
#  'WR': {'Michael Thomas': WR_Michael_Thomas,
#   'DeAndre Hopkins': WR_DeAndre_Hopkins,
#   'Odell Beckham Jr': WR_Odell_Beckham_Jr,
#   'Davante Adams': WR_Davante_Adams,
#   'Antonio Brown': WR_Antonio_Brown,
#   'Tyreek Hill': WR_Tyreek_Hill,
#   'Julio Jones': WR_Julio_Jones,
#   'Adam Thielen': WR_Adam_Thielen,
#   'Robert Woods': WR_Robert_Woods,
#   'Brandin Cooks': WR_Brandin_Cooks,
#   'Mike Evans': WR_Mike_Evans,
#   'Keenan Allen': WR_Keenan_Allen,
#   'Emmanuel Sanders': WR_Emmanuel_Sanders,
#   'JuJu Smith-Schuster': WR_JuJu_Smith_Schuster,
#   'Alshon Jeffery': WR_Alshon_Jeffery,
#   'Kenny Golladay': WR_Kenny_Golladay,
#   'Stefon Diggs': WR_Stefon_Diggs,
#   'Corey Davis': WR_Corey_Davis,
#   'T.Y. Hilton': WR_T.Y._Hilton,
#   'Amari Cooper': WR_Amari_Cooper,
#   'Tyler Boyd': WR_Tyler_Boyd,
#   'Larry Fitzgerald': WR_Larry_Fitzgerald,
#   'Devin Funchess': WR_Devin_Funchess,
#   'Marquez Valdes-Scantling': WR_Marquez_Valdes_Scantling,
#   'Sterling Shepard': WR_Sterling_Shepard,
#   'Doug Baldwin': WR_Doug_Baldwin,
#   'John Brown': WR_John_Brown,
#   'Calvin Ridley': WR_Calvin_Ridley,
#   'Allen Robinson': WR_Allen_Robinson,
#   'Tyler Lockett': WR_Tyler_Lockett,
#   'Golden Tate': WR_Golden_Tate,
#   'DeSean Jackson': WR_DeSean_Jackson,
#   'Demaryius Thomas': WR_Demaryius_Thomas,
#   'Michael Crabtree': WR_Michael_Crabtree,
#   'Christian Kirk': WR_Christian_Kirk,
#   'D.J. Moore': WR_D.J._Moore,
#   'Courtland Sutton': WR_Courtland_Sutton,
#   'Tyrell Williams': WR_Tyrell_Williams,
#   'Anthony Miller': WR_Anthony_Miller,
#   'Donte Moncrief': WR_Donte_Moncrief,
#   'Dede Westbrook': WR_Dede_Westbrook,
#   'Mohamed Sanu': WR_Mohamed_Sanu,
#   'Maurice Harris': WR_Maurice_Harris,
#   'Chris Godwin': WR_Chris_Godwin,
#   'Sammy Watkins': WR_Sammy_Watkins,
#   'Nelson Agholor': WR_Nelson_Agholor,
#   'Cole Beasley': WR_Cole_Beasley,
#   'Josh Doctson': WR_Josh_Doctson,
#   'Adam Humphries': WR_Adam_Humphries,
#   "Tre'Quan Smith": WR_Tre'Quan_Smith,
#   'Seth Roberts': WR_Seth_Roberts,
#   'Brandon LaFell': WR_Brandon_LaFell,
#   'Josh Reynolds': WR_Josh_Reynolds,
#   'John Ross': WR_John_Ross,
#   'Michael Gallup': WR_Michael_Gallup,
#   'Keke Coutee': WR_Keke_Coutee,
#   'Willie Snead': WR_Willie_Snead,
#   'David Moore': WR_David_Moore,
#   'TJ Jones': WR_TJ_Jones,
#   'Curtis Samuel': WR_Curtis_Samuel,
#   'Keelan Cole': WR_Keelan_Cole,
#   'Dontrelle Inman': WR_Dontrelle_Inman,
#   'Tajae Sharpe': WR_Tajae_Sharpe,
#   'Taylor Gabriel': WR_Taylor_Gabriel,
#   'Ryan Grant': WR_Ryan_Grant,
#   'Cameron Batson': WR_Cameron_Batson,
#   'Mike Williams': WR_Mike_Williams,
#   'Equanimeous St. Brown': WR_Equanimeous_St._Brown,
#   'Chris Conley': WR_Chris_Conley,
#   'Chester Rogers': WR_Chester_Rogers,
#   'Laquon Treadwell': WR_Laquon_Treadwell,
#   'Alex Erickson': WR_Alex_Erickson,
#   'Jordan Matthews': WR_Jordan_Matthews,
#   'Bruce Ellington': WR_Bruce_Ellington,
#   'Jarius Wright': WR_Jarius_Wright,
#   'Allen Hurns': WR_Allen_Hurns,
#   'Ryan Switzer': WR_Ryan_Switzer,
#   'Daesean Hamilton': WR_Daesean_Hamilton,
#   'Tim Patrick': WR_Tim_Patrick,
#   'D.J. Chark': WR_D.J._Chark,
#   'Dwayne Harris': WR_Dwayne_Harris,
#   'James Washington': WR_James_Washington,
#   'Cody Core': WR_Cody_Core,
#   'JJ Nelson': WR_JJ_Nelson,
#   'Demarcus Robinson': WR_Demarcus_Robinson,
#   'Travis Benjamin': WR_Travis_Benjamin,
#   'Russell Shepard': WR_Russell_Shepard,
#   'Austin Carr': WR_Austin_Carr,
#   'Aldrick Robinson': WR_Aldrick_Robinson,
#   'Chris Moore': WR_Chris_Moore,
#   'Corey Coleman': WR_Corey_Coleman,
#   'Marcell Ateman': WR_Marcell_Ateman,
#   'Jaron Brown': WR_Jaron_Brown,
#   'Trey Quinn': WR_Trey_Quinn,
#   'Bennie Fowler': WR_Bennie_Fowler,
#   'Chad Beebe': WR_Chad_Beebe,
#   'Darius Jennings': WR_Darius_Jennings,
#   'Marvin Hall': WR_Marvin_Hall,
#   'Justin Hardy': WR_Justin_Hardy,
#   'Michael Floyd': WR_Michael_Floyd,
#   'Keith Kirkwood': WR_Keith_Kirkwood,
#   'Auden Tate': WR_Auden_Tate,
#   'Saeed Blacknall': WR_Saeed_Blacknall,
#   'Josh Bellamy': WR_Josh_Bellamy,
#   'Kendall Wright': WR_Kendall_Wright,
#   'Brandon Zylstra': WR_Brandon_Zylstra},
#  'FLEX': {'Todd Gurley': FLEX_Todd_Gurley,
#   'Saquon Barkley': FLEX_Saquon_Barkley,
#   'Alvin Kamara': FLEX_Alvin_Kamara,
#   'Melvin Gordon': FLEX_Melvin_Gordon,
#   'Ezekiel Elliott': FLEX_Ezekiel_Elliott,
#   'Kareem Hunt': FLEX_Kareem_Hunt,
#   'Christian McCaffrey': FLEX_Christian_McCaffrey,
#   'David Johnson': FLEX_David_Johnson,
#   'James Conner': FLEX_James_Conner,
#   'Leonard Fournette': FLEX_Leonard_Fournette,
#   'Aaron Jones': FLEX_Aaron_Jones,
#   'Joe Mixon': FLEX_Joe_Mixon,
#   'Kerryon Johnson': FLEX_Kerryon_Johnson,
#   'Tevin Coleman': FLEX_Tevin_Coleman,
#   'Dion Lewis': FLEX_Dion_Lewis,
#   'Marlon Mack': FLEX_Marlon_Mack,
#   'Dalvin Cook': FLEX_Dalvin_Cook,
#   'Phillip Lindsay': FLEX_Phillip_Lindsay,
#   'Mark Ingram': FLEX_Mark_Ingram,
#   'Alex Collins': FLEX_Alex_Collins,
#   'Lamar Miller': FLEX_Lamar_Miller,
#   'Tarik Cohen': FLEX_Tarik_Cohen,
#   'Adrian Peterson': FLEX_Adrian_Peterson,
#   'Chris Carson': FLEX_Chris_Carson,
#   'Doug Martin': FLEX_Doug_Martin,
#   'Jordan Howard': FLEX_Jordan_Howard,
#   'Peyton Barber': FLEX_Peyton_Barber,
#   'Mike Davis': FLEX_Mike_Davis,
#   'Theo Riddick': FLEX_Theo_Riddick,
#   'Ito Smith': FLEX_Ito_Smith,
#   'Jalen Richard': FLEX_Jalen_Richard,
#   'Derrick Henry': FLEX_Derrick_Henry,
#   'TJ Yeldon': FLEX_TJ_Yeldon,
#   'Royce Freeman': FLEX_Royce_Freeman,
#   'Nyheim Hines': FLEX_Nyheim_Hines,
#   'Austin Ekeler': FLEX_Austin_Ekeler,
#   'Wendell Smallwood': FLEX_Wendell_Smallwood,
#   'Josh Adams': FLEX_Josh_Adams,
#   'Giovani Bernard': FLEX_Giovani_Bernard,
#   'Kapri Bibbs': FLEX_Kapri_Bibbs,
#   'Javorius Allen': FLEX_Javorius_Allen,
#   'Rashaad Penny': FLEX_Rashaad_Penny,
#   'Latavius Murray': FLEX_Latavius_Murray,
#   'Corey Clement': FLEX_Corey_Clement,
#   'Alfred Blue': FLEX_Alfred_Blue,
#   'Jacquizz Rodgers': FLEX_Jacquizz_Rodgers,
#   'Spencer Ware': FLEX_Spencer_Ware,
#   'Jamaal Williams': FLEX_Jamaal_Williams,
#   'Devontae Booker': FLEX_Devontae_Booker,
#   'Malcolm Brown': FLEX_Malcolm_Brown,
#   'LeGarrette Blount': FLEX_LeGarrette_Blount,
#   'Ty Montgomery': FLEX_Ty_Montgomery,
#   'Chase Edmonds': FLEX_Chase_Edmonds,
#   'Wayne Gallman': FLEX_Wayne_Gallman,
#   'Jaylen Samuels': FLEX_Jaylen_Samuels,
#   'Cameron Artis-Payne': FLEX_Cameron_Artis_Payne,
#   'Jordan Wilkins': FLEX_Jordan_Wilkins,
#   'Carlos Hyde': FLEX_Carlos_Hyde,
#   'Deandre Washington': FLEX_Deandre_Washington,
#   'Gus Edwards': FLEX_Gus_Edwards,
#   'Rod Smith': FLEX_Rod_Smith,
#   'Elijhaa Penny': FLEX_Elijhaa_Penny,
#   'Travis Kelce': FLEX_Travis_Kelce,
#   'Zach Ertz': FLEX_Zach_Ertz,
#   'Greg Olsen': FLEX_Greg_Olsen,
#   'OJ Howard': FLEX_OJ_Howard,
#   'Trey Burton': FLEX_Trey_Burton,
#   'Jordan Reed': FLEX_Jordan_Reed,
#   'Eric Ebron': FLEX_Eric_Ebron,
#   'Jared Cook': FLEX_Jared_Cook,
#   'Austin Hooper': FLEX_Austin_Hooper,
#   'Evan Engram': FLEX_Evan_Engram,
#   'Jack Doyle': FLEX_Jack_Doyle,
#   'Vance McDonald': FLEX_Vance_McDonald,
#   'Jimmy Graham': FLEX_Jimmy_Graham,
#   'Kyle Rudolph': FLEX_Kyle_Rudolph,
#   'Ricky Seals-Jones': FLEX_Ricky_Seals_Jones,
#   'Jeff Heuerman': FLEX_Jeff_Heuerman,
#   'CJ Uzomah': FLEX_CJ_Uzomah,
#   'Benjamin Watson': FLEX_Benjamin_Watson,
#   'Nick Vannett': FLEX_Nick_Vannett,
#   "James O'Shaughnessy": FLEX_James_O'Shaughnessy,
#   'Jonnu Smith': FLEX_Jonnu_Smith,
#   'Mark Andrews': FLEX_Mark_Andrews,
#   'Geoff Swaim': FLEX_Geoff_Swaim,
#   'Jesse James': FLEX_Jesse_James,
#   'Gerald Everett': FLEX_Gerald_Everett,
#   'Luke Willson': FLEX_Luke_Willson,
#   'Tyler Higbee': FLEX_Tyler_Higbee,
#   'Vernon Davis': FLEX_Vernon_Davis,
#   'Cameron Brate': FLEX_Cameron_Brate,
#   'Dallas Goedert': FLEX_Dallas_Goedert,
#   'Ryan Griffin': FLEX_Ryan_Griffin,
#   'Antonio Gates': FLEX_Antonio_Gates,
#   'Hayden Hurst': FLEX_Hayden_Hurst,
#   'Mo Alie-Cox': FLEX_Mo_Alie_Cox,
#   'Virgil Green': FLEX_Virgil_Green,
#   'Jordan Thomas': FLEX_Jordan_Thomas,
#   'Lance Kendricks': FLEX_Lance_Kendricks,
#   'Ed Dickson': FLEX_Ed_Dickson,
#   'Rhett Ellison': FLEX_Rhett_Ellison,
#   'Josh Hill': FLEX_Josh_Hill,
#   'Adam Shaheen': FLEX_Adam_Shaheen,
#   'Demetrius Harris': FLEX_Demetrius_Harris,
#   'Nick Boyle': FLEX_Nick_Boyle,
#   'Blake Bell': FLEX_Blake_Bell,
#   'Luke Stocker': FLEX_Luke_Stocker,
#   'Levine Toilolo': FLEX_Levine_Toilolo,
#   'Jordan Akins': FLEX_Jordan_Akins,
#   'Matt LaCosse': FLEX_Matt_LaCosse,
#   'Jermaine Gresham': FLEX_Jermaine_Gresham,
#   'Jordan Franks': FLEX_Jordan_Franks,
#   'Dalton Schultz': FLEX_Dalton_Schultz,
#   'Dan Arnold': FLEX_Dan_Arnold,
#   'Michael Thomas': FLEX_Michael_Thomas,
#   'DeAndre Hopkins': FLEX_DeAndre_Hopkins,
#   'Odell Beckham Jr': FLEX_Odell_Beckham_Jr,
#   'Davante Adams': FLEX_Davante_Adams,
#   'Antonio Brown': FLEX_Antonio_Brown,
#   'Tyreek Hill': FLEX_Tyreek_Hill,
#   'Julio Jones': FLEX_Julio_Jones,
#   'Adam Thielen': FLEX_Adam_Thielen,
#   'Robert Woods': FLEX_Robert_Woods,
#   'Brandin Cooks': FLEX_Brandin_Cooks,
#   'Mike Evans': FLEX_Mike_Evans,
#   'Keenan Allen': FLEX_Keenan_Allen,
#   'Emmanuel Sanders': FLEX_Emmanuel_Sanders,
#   'JuJu Smith-Schuster': FLEX_JuJu_Smith_Schuster,
#   'Alshon Jeffery': FLEX_Alshon_Jeffery,
#   'Kenny Golladay': FLEX_Kenny_Golladay,
#   'Stefon Diggs': FLEX_Stefon_Diggs,
#   'Corey Davis': FLEX_Corey_Davis,
#   'T.Y. Hilton': FLEX_T.Y._Hilton,
#   'Amari Cooper': FLEX_Amari_Cooper,
#   'Tyler Boyd': FLEX_Tyler_Boyd,
#   'Larry Fitzgerald': FLEX_Larry_Fitzgerald,
#   'Devin Funchess': FLEX_Devin_Funchess,
#   'Marquez Valdes-Scantling': FLEX_Marquez_Valdes_Scantling,
#   'Sterling Shepard': FLEX_Sterling_Shepard,
#   'Doug Baldwin': FLEX_Doug_Baldwin,
#   'John Brown': FLEX_John_Brown,
#   'Calvin Ridley': FLEX_Calvin_Ridley,
#   'Allen Robinson': FLEX_Allen_Robinson,
#   'Tyler Lockett': FLEX_Tyler_Lockett,
#   'Golden Tate': FLEX_Golden_Tate,
#   'DeSean Jackson': FLEX_DeSean_Jackson,
#   'Demaryius Thomas': FLEX_Demaryius_Thomas,
#   'Michael Crabtree': FLEX_Michael_Crabtree,
#   'Christian Kirk': FLEX_Christian_Kirk,
#   'D.J. Moore': FLEX_D.J._Moore,
#   'Courtland Sutton': FLEX_Courtland_Sutton,
#   'Tyrell Williams': FLEX_Tyrell_Williams,
#   'Anthony Miller': FLEX_Anthony_Miller,
#   'Donte Moncrief': FLEX_Donte_Moncrief,
#   'Dede Westbrook': FLEX_Dede_Westbrook,
#   'Mohamed Sanu': FLEX_Mohamed_Sanu,
#   'Maurice Harris': FLEX_Maurice_Harris,
#   'Chris Godwin': FLEX_Chris_Godwin,
#   'Sammy Watkins': FLEX_Sammy_Watkins,
#   'Nelson Agholor': FLEX_Nelson_Agholor,
#   'Cole Beasley': FLEX_Cole_Beasley,
#   'Josh Doctson': FLEX_Josh_Doctson,
#   'Adam Humphries': FLEX_Adam_Humphries,
#   "Tre'Quan Smith": FLEX_Tre'Quan_Smith,
#   'Seth Roberts': FLEX_Seth_Roberts,
#   'Brandon LaFell': FLEX_Brandon_LaFell,
#   'Josh Reynolds': FLEX_Josh_Reynolds,
#   'John Ross': FLEX_John_Ross,
#   'Michael Gallup': FLEX_Michael_Gallup,
#   'Keke Coutee': FLEX_Keke_Coutee,
#   'Willie Snead': FLEX_Willie_Snead,
#   'David Moore': FLEX_David_Moore,
#   'TJ Jones': FLEX_TJ_Jones,
#   'Curtis Samuel': FLEX_Curtis_Samuel,
#   'Keelan Cole': FLEX_Keelan_Cole,
#   'Dontrelle Inman': FLEX_Dontrelle_Inman,
#   'Tajae Sharpe': FLEX_Tajae_Sharpe,
#   'Taylor Gabriel': FLEX_Taylor_Gabriel,
#   'Ryan Grant': FLEX_Ryan_Grant,
#   'Cameron Batson': FLEX_Cameron_Batson,
#   'Mike Williams': FLEX_Mike_Williams,
#   'Equanimeous St. Brown': FLEX_Equanimeous_St._Brown,
#   'Chris Conley': FLEX_Chris_Conley,
#   'Chester Rogers': FLEX_Chester_Rogers,
#   'Laquon Treadwell': FLEX_Laquon_Treadwell,
#   'Alex Erickson': FLEX_Alex_Erickson,
#   'Jordan Matthews': FLEX_Jordan_Matthews,
#   'Bruce Ellington': FLEX_Bruce_Ellington,
#   'Jarius Wright': FLEX_Jarius_Wright,
#   'Allen Hurns': FLEX_Allen_Hurns,
#   'Ryan Switzer': FLEX_Ryan_Switzer,
#   'Daesean Hamilton': FLEX_Daesean_Hamilton,
#   'Tim Patrick': FLEX_Tim_Patrick,
#   'D.J. Chark': FLEX_D.J._Chark,
#   'Dwayne Harris': FLEX_Dwayne_Harris,
#   'James Washington': FLEX_James_Washington,
#   'Cody Core': FLEX_Cody_Core,
#   'JJ Nelson': FLEX_JJ_Nelson,
#   'Demarcus Robinson': FLEX_Demarcus_Robinson,
#   'Travis Benjamin': FLEX_Travis_Benjamin,
#   'Russell Shepard': FLEX_Russell_Shepard,
#   'Austin Carr': FLEX_Austin_Carr,
#   'Aldrick Robinson': FLEX_Aldrick_Robinson,
#   'Chris Moore': FLEX_Chris_Moore,
#   'Corey Coleman': FLEX_Corey_Coleman,
#   'Marcell Ateman': FLEX_Marcell_Ateman,
#   'Jaron Brown': FLEX_Jaron_Brown,
#   'Trey Quinn': FLEX_Trey_Quinn,
#   'Bennie Fowler': FLEX_Bennie_Fowler,
#   'Chad Beebe': FLEX_Chad_Beebe,
#   'Darius Jennings': FLEX_Darius_Jennings,
#   'Marvin Hall': FLEX_Marvin_Hall,
#   'Justin Hardy': FLEX_Justin_Hardy,
#   'Michael Floyd': FLEX_Michael_Floyd,
#   'Keith Kirkwood': FLEX_Keith_Kirkwood,
#   'Auden Tate': FLEX_Auden_Tate,
#   'Saeed Blacknall': FLEX_Saeed_Blacknall,
#   'Josh Bellamy': FLEX_Josh_Bellamy,
#   'Kendall Wright': FLEX_Kendall_Wright,
#   'Brandon Zylstra': FLEX_Brandon_Zylstra}}

# %%
prob = LpProblem("Fantasy", LpMaximize)
rewards = []
costs = []
position_constraints = []

# Setting up the rewards, costs, and positional constraints
for k, v in _vars.items():
    costs += lpSum([salaries[k][i] * _vars[k][i] for i in v])
    rewards += lpSum([points[k][i] * _vars[k][i] for i in v])
    prob += lpSum([_vars[k][i] for i in v]) == pos_num_available[k]
    
# Setting up constraint to not pick the same player for 2 positions   
for position_name in ('WR', 'RB', 'TE'):
    for player in _vars[position_name]:
        prob += lpSum([_vars[p][player] for p in ['FLEX', position_name]]) <= 1
    
prob += lpSum(rewards)
prob += lpSum(costs) <= SALARY_CAP

#print(prob)

# %%
prob.solve()
# Out:
# 1

# %%
def summary(prob):
    div = '---------------------------------------\n'
    print("Variables:\n")
    score = str(prob.objective)
    constraints = [str(const) for const in prob.constraints.values()]
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraints = [const.replace(v.name, str(v.varValue)) for const in constraints]
        if v.varValue != 0:
            print(v.name, "=", v.varValue)
    print(div)
    print("Constraints:")
    for constraint in constraints:
        constraint_pretty = " + ".join(re.findall("[0-9\.]*\*1.0", constraint))
        if constraint_pretty != "":
            print("{} = {}".format(constraint_pretty, eval(constraint_pretty)))
    print(div)
    print("Score:")
    score_pretty = " + ".join(re.findall("[0-9\.]+\*1.0", score))
    print("{} = {}".format(score_pretty, eval(score)))

# %%
summary(prob)
# Out:
# Variables:
#
# DST_Seattle_Seahawks = 1.0
# FLEX_John_Brown = 1.0
# K_Wil_Lutz = 1.0
# QB_Carson_Wentz = 1.0
# RB_David_Johnson = 1.0
# RB_Dion_Lewis = 1.0
# TE_James_O'Shaughnessy = 1.0
# WR_Devin_Funchess = 1.0
# WR_Marquez_Valdes_Scantling = 1.0
# ---------------------------------------
#
# Constraints:
# 3100*1.0 + 5400*1.0 + 5000*1.0 + 7700*1.0 + 7900*1.0 + 5900*1.0 + 4000*1.0 + 5700*1.0 + 5300*1.0 = 50000.0
# ---------------------------------------
#
# Score:
# 6.7*1.0 + 10.19*1.0 + 11.28*1.0 + 21.25*1.0 + 18.56*1.0 + 12.16*1.0 + 5.43*1.0 + 10.95*1.0 + 10.88*1.0 = 107.39999999999999

# %% [markdown]
# #### Week 1
#
# Variables:
#
# DST_Miami_Dolphins = 1.0 <br>
# FLEX_James_Conner = 1.0 <br>
# K_Randy_Bullock = 1.0 <br>
# QB_Ryan_Fitzpatrick = 1.0 <br>
# RB_Alvin_Kamara = 1.0 <br>
# RB_David_Johnson = 1.0 <br>
# TE_Dallas_Goedert = 1.0 <br>
# WR_Keelan_Cole = 1.0 <br>
# WR_Nelson_Agholor = 1.0
#
# **---------------------------------------**
#
# Constraints:
# 3200*1.0 + 5000*1.0 + 3900*1.0 + 6200*1.0 + 8700*1.0 + 8600*1.0 + 4000*1.0 + 4500*1.0 + 5900*1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 6.2*1.0 + 12.76*1.0 + 7.89*1.0 + 15.58*1.0 + 19.72*1.0 + 19.52*1.0 + 4.57*1.0 + 8.85*1.0 + 10.6*1.0 = 105.69

# %% [markdown]
# #### Week 11
#
# Variables:
#
# DST_Seattle_Seahawks = 1.0 <br>
# FLEX_John_Brown = 1.0 <br>
# K_Wil_Lutz = 1.0 <br>
# QB_Carson_Wentz = 1.0 <br>
# RB_David_Johnson = 1.0 <br>
# RB_Dion_Lewis = 1.0 <br>
# TE_James_O'Shaughnessy = 1.0 <br>
# WR_Devin_Funchess = 1.0 <br>
# WR_Marquez_Valdes_Scantling = 1.0 <br>
#
# **---------------------------------------**
#
# Constraints:
# 3100*1.0 + 5400*1.0 + 5000*1.0 + 7700*1.0 + 7900*1.0 + 5900*1.0 + 4000*1.0 + 5700*1.0 + 5300*1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 6.7*1.0 + 10.19*1.0 + 11.28*1.0 + 21.25*1.0 + 18.56*1.0 + 12.16*1.0 + 5.43*1.0 + 10.95*1.0 + 10.88*1.0 = 107.39999999999999

# %% [markdown]
# #### Week 12
#
# Variables:
#
# DST_Cleveland_Browns = 1.0 <br>
# FLEX_James_Conner = 1.0 <br>
# K_Wil_Lutz = 1.0 <br>
# QB_Nick_Mullens = 1.0 <br>
# RB_Gus_Edwards = 1.0 <br>
# RB_Matt_Breida = 1.0 <br>
# TE_Cameron_Brate = 1.0 <br>
# WR_D.J._Moore = 1.0 <br>
# WR_Jarvis_Landry = 1.0 <br>
#
# **---------------------------------------**
#
# Constraints:
# 3100*1.0 + 7900*1.0 + 5000*1.0 + 6000*1.0 + 5300*1.0 + 6400*1.0 + 4400*1.0 + 5800*1.0 + 6100*1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 6.6*1.0 + 18.39*1.0 + 11.51*1.0 + 16.69*1.0 + 10.23*1.0 + 13.51*1.0 + 8.03*1.0 + 10.5*1.0 + 11.15*1.0 = 106.61000000000001
