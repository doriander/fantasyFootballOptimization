# %% [markdown]
# ## Project code
# #### Using PuLP,  a python library for optimizaiton probelms
#
# - Identify the Decision Variables
# - Formulate the Objective Function using the decision variables, maximize total score
# - Formulate the Constraints, in terms of the decision variables.
# - Identify the Data needed for the objective function and constraints

# %% [markdown]
# ### Import Libraries

# %%
import urllib, json
import pandas as pd
import re
from itertools import permutations
from pulp import *

# %% [markdown]
# ### Reading th Fantasy Football Salary and Porjection

# %%
dataset = pd.read_csv("fantasy_football_salary_and_projection_w1.csv", header = 0)
print(dataset.shape)
dataset.head(10)
# Out:
# (300, 10)
#    Rank                  Name Team Position  Week Opponent  \
# 0    83      Baltimore Ravens  BAL      DST     1      BUF
# 1   100  Jacksonville Jaguars  JAX      DST     1      NYG
# 2   110    New Orleans Saints   NO      DST     1       TB
# 3   123         Detroit Lions  DET      DST     1      NYJ
# 4   129   Pittsburgh Steelers  PIT      DST     1      CLE
# 5   145      Tennessee Titans  TEN      DST     1      MIA
# 6   145  New England Patriots   NE      DST     1      HOU
# 7   157   Washington Redskins  WAS      DST     1      ARI
# 8   161     Green Bay Packers   GB      DST     1      CHI
# 9   164     Minnesota Vikings  MIN      DST     1       SF
#
#    UpcomingOpponentRank  UpcomingOpponentPositionRank  FanDuelSalary  \
# 0                   NaN                           NaN           4800
# 1                   NaN                           NaN           4700
# 2                   NaN                           NaN           4600
# 3                   NaN                           NaN           4700
# 4                   NaN                           NaN           4200
# 5                   NaN                           NaN           4200
# 6                   NaN                           NaN           4200
# 7                   NaN                           NaN           4000
# 8                   NaN                           NaN           4100
# 9                   NaN                           NaN           4500
#
#    FantasyPointsFanDuel
# 0                  10.3
# 1                   9.7
# 2                   9.1
# 3                   8.5
# 4                   8.4
# 5                   8.1
# 6                   8.1
# 7                   8.0
# 8                   7.9
# 9                   7.8

# %% [markdown]
# ### Clean Data
# #### Drop columns that aren't used

# %%
dataset = dataset.drop(['Team', 'Week', 'Opponent', 'UpcomingOpponentRank', 'UpcomingOpponentPositionRank'], axis = 1)
dataset.head(10)
# Out:
#    Rank                  Name Position  FanDuelSalary  FantasyPointsFanDuel
# 0    83      Baltimore Ravens      DST           4800                  10.3
# 1   100  Jacksonville Jaguars      DST           4700                   9.7
# 2   110    New Orleans Saints      DST           4600                   9.1
# 3   123         Detroit Lions      DST           4700                   8.5
# 4   129   Pittsburgh Steelers      DST           4200                   8.4
# 5   145      Tennessee Titans      DST           4200                   8.1
# 6   145  New England Patriots      DST           4200                   8.1
# 7   157   Washington Redskins      DST           4000                   8.0
# 8   161     Green Bay Packers      DST           4100                   7.9
# 9   164     Minnesota Vikings      DST           4500                   7.8

# %% [markdown]
# #### Add FLEX position tag to eligible players (RB, WR, TE)

# %%
flex = dataset[dataset.Position.isin(["RB","WR","TE"])].copy()
flex.Position = "FLEX"
dataset = pd.concat([dataset, flex])
dataset = dataset.drop('Rank', axis=1)

dataset.head()
# Out:
#                    Name Position  FanDuelSalary  FantasyPointsFanDuel
# 0      Baltimore Ravens      DST           4800                  10.3
# 1  Jacksonville Jaguars      DST           4700                   9.7
# 2    New Orleans Saints      DST           4600                   9.1
# 3         Detroit Lions      DST           4700                   8.5
# 4   Pittsburgh Steelers      DST           4200                   8.4

# %% [markdown]
# #### Attach salaries and scores on position

# %%
dataset[dataset.Position=="QB"].head(15)

salaries = {}
points = {}
for pos in dataset.Position.unique():
    available_pos = dataset[dataset.Position == pos]
    salary = list(available_pos[["Name","FanDuelSalary"]].set_index("Name").to_dict().values())[0]
    point = list(available_pos[["Name","FantasyPointsFanDuel"]].set_index("Name").to_dict().values())[0]
    salaries[pos] = salary
    points[pos] = point

pos_num_available = {
    "QB": 1,
    "RB": 2,
    "WR": 2,
    "TE": 1,
    "DST": 1,
    "K": 1,
    "FLEX": 1
}

# %% [markdown]
# ### Add Constraints and Setup Problem
# #### Salaries and Positional

# %%
SALARY_CAP = 50000
_vars = {k: LpVariable.dict(k, v, cat="Binary") for k, v in points.items()}

# %%
prob = LpProblem("Fantasy", LpMaximize)
rewards = []
costs = []
position_constraints = []

# Setting up the rewards, costs, and positional constraints
for k, v in _vars.items():
    costs += lpSum([salaries[k][i] * _vars[k][i] for i in v])
    rewards += lpSum([points[k][i] * _vars[k][i] for i in v])
    prob += lpSum([_vars[k][i] for i in v]) == pos_num_available[k]
    
# Setting up constraint to not pick the same player for 2 positions   
for position_name in ('WR', 'RB', 'TE'):
    for player in _vars[position_name]:
        prob += lpSum([_vars[p][player] for p in ['FLEX', position_name]]) <= 1
    
prob += lpSum(rewards)
prob += lpSum(costs) <= SALARY_CAP

print(prob)
# Out:
# Fantasy:
# MAXIMIZE
# 7.3*DST_Arizona_Cardinals + 6.0*DST_Atlanta_Falcons + 10.3*DST_Baltimore_Ravens + 5.7*DST_Buffalo_Bills + 7.7*DST_Carolina_Panthers + 6.8*DST_Chicago_Bears + 7.5*DST_Cincinnati_Bengals + 4.6*DST_Cleveland_Browns + 6.1*DST_Dallas_Cowboys + 7.8*DST_Denver_Broncos + 8.5*DST_Detroit_Lions + 7.9*DST_Green_Bay_Packers + 4.8*DST_Houston_Texans + 4.9*DST_Indianapolis_Colts + 9.7*DST_Jacksonville_Jaguars + 5.8*DST_Kansas_City_Chiefs + 6.9*DST_Los_Angeles_Chargers + 7.8*DST_Los_Angeles_Rams + 6.2*DST_Miami_Dolphins + 7.8*DST_Minnesota_Vikings + 8.1*DST_New_England_Patriots + 9.1*DST_New_Orleans_Saints + 5.7*DST_New_York_Giants + 6.1*DST_New_York_Jets + 5.2*DST_Oakland_Raiders + 6.1*DST_Philadelphia_Eagles + 8.4*DST_Pittsburgh_Steelers + 5.1*DST_San_Francisco_49ers + 7.5*DST_Seattle_Seahawks + 4.2*DST_Tampa_Bay_Buccaneers + 8.1*DST_Tennessee_Titans + 8.0*DST_Washington_Redskins + 14.26*FLEX_AJ_Green + 4.88*FLEX_Adam_Humphries + 12.28*FLEX_Adam_Thielen + 7.36*FLEX_Adrian_Peterson + 6.66*FLEX_Albert_Wilson + 12.36*FLEX_Alex_Collins + 4.53*FLEX_Alfred_Blue + 7.07*FLEX_Alfred_Morris + 7.27*FLEX_Allen_Hurns + 10.09*FLEX_Allen_Robinson + 19.72*FLEX_Alvin_Kamara + 11.09*FLEX_Amari_Cooper + 6.36*FLEX_Anthony_Miller + 16.99*FLEX_Antonio_Brown + 5.05*FLEX_Antonio_Callaway + 5.19*FLEX_Antonio_Gates + 5.27*FLEX_Austin_Carr + 5.59*FLEX_Austin_Ekeler + 5.59*FLEX_Austin_Hooper + 6.48*FLEX_Austin_Seferian_Jenkins + 6.59*FLEX_Benjamin_Watson + 8.64*FLEX_Bilal_Powell + 3.29*FLEX_Blake_Jarwin + 10.82*FLEX_Brandin_Cooks + 4.52*FLEX_Brandon_Marshall + 6.22*FLEX_Bruce_Ellington + 5.41*FLEX_CJ_Anderson + 6.32*FLEX_Calvin_Ridley + 6.03*FLEX_Cameron_Brate + 9.74*FLEX_Carlos_Hyde + 5.09*FLEX_Chad_Williams + 6.84*FLEX_Charles_Clay + 3.95*FLEX_Chase_Edmonds + 4.67*FLEX_Chester_Rogers + 8.24*FLEX_Chris_Carson + 3.78*FLEX_Chris_Conley + 6.44*FLEX_Chris_Godwin + 12.14*FLEX_Chris_Hogan + 3.68*FLEX_Chris_Ivory + 8.45*FLEX_Chris_Thompson + 5.51*FLEX_Christian_Kirk + 14.94*FLEX_Christian_McCaffrey + 3.56*FLEX_Christine_Michael + 3.68*FLEX_Cody_Latimer + 4.81*FLEX_Cole_Beasley + 9.94*FLEX_Cooper_Kupp + 4.18*FLEX_Cordarrelle_Patterson + 6.44*FLEX_Corey_Clement + 9.64*FLEX_Corey_Davis + 3.32*FLEX_Corey_Grant + 5.92*FLEX_Courtland_Sutton + 3.4*FLEX_D.J._Chark + 5.9*FLEX_D.J._Moore + 4.57*FLEX_Dallas_Goedert + 13.87*FLEX_Dalvin_Cook + 7.96*FLEX_Danny_Amendola + 5.8*FLEX_Darren_Sproles + 13.16*FLEX_Davante_Adams + 19.52*FLEX_David_Johnson + 6.77*FLEX_David_Njoku + 16.25*FLEX_DeAndre_Hopkins + 8.06*FLEX_DeSean_Jackson + 7.24*FLEX_Dede_Westbrook + 9.88*FLEX_Delanie_Walker + 11.72*FLEX_Demaryius_Thomas + 11.2*FLEX_Derrick_Henry + 9.61*FLEX_Devin_Funchess + 12.98*FLEX_Devonta_Freeman + 6.48*FLEX_Devontae_Booker + 9.57*FLEX_Dion_Lewis + 6.51*FLEX_Donte_Moncrief + 11.07*FLEX_Doug_Baldwin + 4.6*FLEX_Doug_Martin + 8.04*FLEX_Duke_Johnson + 10.02*FLEX_Emmanuel_Sanders + 5.79*FLEX_Eric_Ebron + 8.44*FLEX_Evan_Engram + 16.51*FLEX_Ezekiel_Elliott + 5.38*FLEX_Frank_Gore + 6.88*FLEX_George_Kittle + 5.76*FLEX_Geronimo_Allison + 7.22*FLEX_Giovani_Bernard + 11.74*FLEX_Golden_Tate + 9.86*FLEX_Greg_Olsen + 8.34*FLEX_Isaiah_Crowell + 4.4*FLEX_JJ_Nelson + 8.67*FLEX_Jack_Doyle + 3.22*FLEX_Jakeem_Grant + 3.74*FLEX_Jalen_Richard + 11.38*FLEX_Jamaal_Williams + 12.76*FLEX_James_Conner + 5.5*FLEX_James_Washington + 8.42*FLEX_James_White + 9.44*FLEX_Jamison_Crowder + 7.04*FLEX_Jared_Cook + 3.64*FLEX_Jaron_Brown + 11.15*FLEX_Jarvis_Landry + 6.67*FLEX_Javorius_Allen + 10.4*FLEX_Jay_Ajayi + 5.16*FLEX_Jaylen_Samuels + 5.09*FLEX_Jeremy_Hill + 3.66*FLEX_Jeremy_Kerley + 5.51*FLEX_Jesse_James + 8.93*FLEX_Jimmy_Graham + 12.36*FLEX_Joe_Mixon + 6.99*FLEX_John_Brown + 6.76*FLEX_John_Ross + 11.94*FLEX_Jordan_Howard + 8.12*FLEX_Jordan_Reed + 7.7*FLEX_Jordan_Wilkins + 8.42*FLEX_Jordy_Nelson + 7.19*FLEX_Josh_Doctson + 8.4*FLEX_Josh_Gordon + 10.56*FLEX_JuJu_Smith_Schuster + 14.43*FLEX_Julio_Jones + 15.12*FLEX_Kareem_Hunt + 8.85*FLEX_Keelan_Cole + 14.37*FLEX_Keenan_Allen + 8.29*FLEX_Kelvin_Benjamin + 3.98*FLEX_Kenneth_Dixon  ...
# SUBJECT TO
# _C1: DST_Arizona_Cardinals + DST_Atlanta_Falcons + DST_Baltimore_Ravens
#  + DST_Buffalo_Bills + DST_Carolina_Panthers + DST_Chicago_Bears
#  + DST_Cincinnati_Bengals + DST_Cleveland_Browns + DST_Dallas_Cowboys
#  + DST_Denver_Broncos + DST_Detroit_Lions + DST_Green_Bay_Packers
#  + DST_Houston_Texans + DST_Indianapolis_Colts + DST_Jacksonville_Jaguars
#  + DST_Kansas_City_Chiefs + DST_Los_Angeles_Chargers + DST_Los_Angeles_Rams
#  + DST_Miami_Dolphins + DST_Minnesota_Vikings + DST_New_England_Patriots
#  + DST_New_Orleans_Saints + DST_New_York_Giants + DST_New_York_Jets
#  + DST_Oakland_Raiders + DST_Philadelphia_Eagles + DST_Pittsburgh_Steelers
#  + DST_San_Francisco_49ers + DST_Seattle_Seahawks + DST_Tampa_Bay_Buccaneers
#  + DST_Tennessee_Titans + DST_Washington_Redskins = 1
#
# _C2: K_Adam_Vinatieri + K_Aldrick_Rosas + K_Brandon_McManus + K_Brett_Maher
#  + K_Caleb_Sturgis + K_Chandler_Catanzaro + K_Chris_Boswell + K_Cody_Parkey
#  + K_Daniel_Carlson + K_Dustin_Hopkins + K_Graham_Gano + K_Greg_Zuerlein
#  + K_Harrison_Butker + K_Jake_Elliott + K_Jason_Myers + K_Jason_Sanders
#  + K_Josh_Lambo + K_Justin_Tucker + K_Ka'imi_Fairbairn + K_Mason_Crosby
#  + K_Matt_Bryant + K_Matt_Prater + K_Mike_Nugent + K_Phil_Dawson
#  + K_Randy_Bullock + K_Robbie_Gould + K_Ryan_Succop + K_Sebastian_Janikowski
#  + K_Stephen_Gostkowski + K_Steven_Hauschka + K_Wil_Lutz + K_Zane_Gonzalez = 1
#
# _C3: QB_Aaron_Rodgers + QB_Alex_Smith + QB_Andrew_Luck + QB_Andy_Dalton
#  + QB_Ben_Roethlisberger + QB_Blake_Bortles + QB_Cam_Newton + QB_Case_Keenum
#  + QB_Dak_Prescott + QB_Derek_Carr + QB_Deshaun_Watson + QB_Drew_Brees
#  + QB_Eli_Manning + QB_Jared_Goff + QB_Jimmy_Garoppolo + QB_Joe_Flacco
#  + QB_Kirk_Cousins + QB_Marcus_Mariota + QB_Matt_Ryan + QB_Matthew_Stafford
#  + QB_Mitch_Trubisky + QB_Nathan_Peterman + QB_Nick_Foles + QB_Patrick_Mahomes
#  + QB_Philip_Rivers + QB_Russell_Wilson + QB_Ryan_Fitzpatrick
#  + QB_Ryan_Tannehill + QB_Sam_Bradford + QB_Sam_Darnold + QB_Tom_Brady
#  + QB_Tyrod_Taylor = 1
#
# _C4: RB_Adrian_Peterson + RB_Alex_Collins + RB_Alfred_Blue + RB_Alfred_Morris
#  + RB_Alvin_Kamara + RB_Austin_Ekeler + RB_Bilal_Powell + RB_CJ_Anderson
#  + RB_Carlos_Hyde + RB_Chase_Edmonds + RB_Chris_Carson + RB_Chris_Ivory
#  + RB_Chris_Thompson + RB_Christian_McCaffrey + RB_Christine_Michael
#  + RB_Corey_Clement + RB_Corey_Grant + RB_Dalvin_Cook + RB_Darren_Sproles
#  + RB_David_Johnson + RB_Derrick_Henry + RB_Devonta_Freeman
#  + RB_Devontae_Booker + RB_Dion_Lewis + RB_Doug_Martin + RB_Duke_Johnson
#  + RB_Ezekiel_Elliott + RB_Frank_Gore + RB_Giovani_Bernard + RB_Isaiah_Crowell
#  + RB_Jalen_Richard + RB_Jamaal_Williams + RB_James_Conner + RB_James_White
#  + RB_Javorius_Allen + RB_Jay_Ajayi + RB_Jaylen_Samuels + RB_Jeremy_Hill
#  + RB_Joe_Mixon + RB_Jordan_Howard + RB_Jordan_Wilkins + RB_Kareem_Hunt
#  + RB_Kenneth_Dixon + RB_Kenyan_Drake + RB_Kerryon_Johnson + RB_Kyle_Juszczyk
#  + RB_Lamar_Miller + RB_Latavius_Murray + RB_LeGarrette_Blount
#  + RB_LeSean_McCoy + RB_Leonard_Fournette + RB_Marshawn_Lynch + RB_Matt_Breida
#  + RB_Melvin_Gordon + RB_Mike_Gillislee + RB_Nyheim_Hines + RB_Peyton_Barber
#  + RB_Rashaad_Penny + RB_Rex_Burkhead + RB_Royce_Freeman + RB_Saquon_Barkley
#  + RB_Spencer_Ware + RB_TJ_Yeldon + RB_Tarik_Cohen + RB_Tevin_Coleman
#  + RB_Theo_Riddick + RB_Todd_Gurley + RB_Ty_Montgomery = 2
#
# _C5: TE_Antonio_Gates + TE_Austin_Hooper + TE_Austin_Seferian_Jenkins
#  + TE_Benjamin_Watson + TE_Blake_Jarwin + TE_Cameron_Brate + TE_Charles_Clay
#  + TE_Dallas_Goedert + TE_David_Njoku + TE_Delanie_Walker + TE_Eric_Ebron
#  + TE_Evan_Engram + TE_George_Kittle + TE_Greg_Olsen + TE_Jack_Doyle
#  + TE_Jared_Cook + TE_Jesse_James + TE_Jimmy_Graham + TE_Jordan_Reed
#  + TE_Kyle_Rudolph + TE_Luke_Willson + TE_Mike_Gesicki + TE_Nick_Vannett
#  + TE_OJ_Howard + TE_Ricky_Seals_Jones + TE_Rob_Gronkowski + TE_Ryan_Griffin
#  + TE_Travis_Kelce + TE_Trey_Burton + TE_Tyler_Eifert + TE_Tyler_Higbee
#  + TE_Vernon_Davis + TE_Zach_Ertz = 1
#
# _C6: WR_AJ_Green + WR_Adam_Humphries + WR_Adam_Thielen + WR_Albert_Wilson
#  + WR_Allen_Hurns + WR_Allen_Robinson + WR_Amari_Cooper + WR_Anthony_Miller
#  + WR_Antonio_Brown + WR_Antonio_Callaway + WR_Austin_Carr + WR_Brandin_Cooks
#  + WR_Brandon_Marshall + WR_Bruce_Ellington + WR_Calvin_Ridley
#  + WR_Chad_Williams + WR_Chester_Rogers + WR_Chris_Conley + WR_Chris_Godwin
#  + WR_Chris_Hogan + WR_Christian_Kirk + WR_Cody_Latimer + WR_Cole_Beasley
#  + WR_Cooper_Kupp + WR_Cordarrelle_Patterson + WR_Corey_Davis
#  + WR_Courtland_Sutton + WR_D.J._Chark + WR_D.J._Moore + WR_Danny_Amendola
#  + WR_Davante_Adams + WR_DeAndre_Hopkins + WR_DeSean_Jackson
#  + WR_Dede_Westbrook + WR_Demaryius_Thomas + WR_Devin_Funchess
#  + WR_Donte_Moncrief + WR_Doug_Baldwin + WR_Emmanuel_Sanders
#  + WR_Geronimo_Allison + WR_Golden_Tate + WR_JJ_Nelson + WR_Jakeem_Grant
#  + WR_James_Washington + WR_Jamison_Crowder + WR_Jaron_Brown
#  + WR_Jarvis_Landry + WR_Jeremy_Kerley + WR_John_Brown + WR_John_Ross
#  + WR_Jordy_Nelson + WR_Josh_Doctson + WR_Josh_Gordon + WR_JuJu_Smith_Schuster
#  + WR_Julio_Jones + WR_Keelan_Cole + WR_Keenan_Allen + WR_Kelvin_Benjamin
#  + WR_Kenny_Golladay + WR_Kenny_Stills + WR_Kevin_White + WR_Laquon_Treadwell
#  + WR_Larry_Fitzgerald + WR_Marquise_Goodwin + WR_Marvin_Jones
#  + WR_Michael_Crabtree + WR_Michael_Gallup + WR_Michael_Thomas + WR_Mike_Evans
#  + WR_Mike_Wallace + WR_Mike_Williams + WR_Mohamed_Sanu + WR_Nelson_Agholor
#  + WR_Odell_Beckham_Jr + WR_Paul_Richardson + WR_Phillip_Dorsett
#  + WR_Pierre_Garcon + WR_Quincy_Enunwa + WR_Randall_Cobb + WR_Rishard_Matthews
#  + WR_Robby_Anderson + WR_Robert_Woods + WR_Ryan_Grant + WR_Sammy_Watkins
#  + WR_Seth_Roberts + WR_Stefon_Diggs + WR_Sterling_Shepard + WR_T.Y._Hilton
#  + WR_Taylor_Gabriel + WR_Taywan_Taylor + WR_Ted_Ginn + WR_Terrance_Williams
#  + WR_Terrelle_Pryor + WR_Torrey_Smith + WR_Travis_Benjamin
#  + WR_Tre'Quan_Smith + WR_Trent_Taylor + WR_Tyler_Boyd + WR_Tyler_Lockett
#  + WR_Tyreek_Hill + WR_Tyrell_Williams + WR_Willie_Snead + WR_Zay_Jones = 2
#
# _C7: FLEX_AJ_Green + FLEX_Adam_Humphries + FLEX_Adam_Thielen
#  + FLEX_Adrian_Peterson + FLEX_Albert_Wilson + FLEX_Alex_Collins
#  + FLEX_Alfred_Blue + FLEX_Alfred_Morris + FLEX_Allen_Hurns
#  + FLEX_Allen_Robinson + FLEX_Alvin_Kamara + FLEX_Amari_Cooper
#  + FLEX_Anthony_Miller + FLEX_Antonio_Brown + FLEX_Antonio_Callaway
#  + FLEX_Antonio_Gates + FLEX_Austin_Carr + FLEX_Austin_Ekeler
#  + FLEX_Austin_Hooper + FLEX_Austin_Seferian_Jenkins + FLEX_Benjamin_Watson
#  + FLEX_Bilal_Powell + FLEX_Blake_Jarwin + FLEX_Brandin_Cooks
#  + FLEX_Brandon_Marshall + FLEX_Bruce_Ellington + FLEX_CJ_Anderson
#  + FLEX_Calvin_Ridley + FLEX_Cameron_Brate + FLEX_Carlos_Hyde
#  + FLEX_Chad_Williams + FLEX_Charles_Clay + FLEX_Chase_Edmonds
#  + FLEX_Chester_Rogers + FLEX_Chris_Carson + FLEX_Chris_Conley
#  + FLEX_Chris_Godwin + FLEX_Chris_Hogan + FLEX_Chris_Ivory
#  + FLEX_Chris_Thompson + FLEX_Christian_Kirk + FLEX_Christian_McCaffrey
#  + FLEX_Christine_Michael + FLEX_Cody_Latimer + FLEX_Cole_Beasley
#  + FLEX_Cooper_Kupp + FLEX_Cordarrelle_Patterson + FLEX_Corey_Clement
#  + FLEX_Corey_Davis + FLEX_Corey_Grant + FLEX_Courtland_Sutton
#  + FLEX_D.J._Chark + FLEX_D.J._Moore + FLEX_Dallas_Goedert + FLEX_Dalvin_Cook
#  + FLEX_Danny_Amendola + FLEX_Darren_Sproles + FLEX_Davante_Adams
#  + FLEX_David_Johnson + FLEX_David_Njoku + FLEX_DeAndre_Hopkins
#  + FLEX_DeSean_Jackson + FLEX_Dede_Westbrook + FLEX_Delanie_Walker
#  + FLEX_Demaryius_Thomas + FLEX_Derrick_Henry + FLEX_Devin_Funchess
#  + FLEX_Devonta_Freeman + FLEX_Devontae_Booker + FLEX_Dion_Lewis
#  + FLEX_Donte_Moncrief + FLEX_Doug_Baldwin + FLEX_Doug_Martin
#  + FLEX_Duke_Johnson + FLEX_Emmanuel_Sanders + FLEX_Eric_Ebron
#  + FLEX_Evan_Engram + FLEX_Ezekiel_Elliott + FLEX_Frank_Gore
#  + FLEX_George_Kittle + FLEX_Geronimo_Allison + FLEX_Giovani_Bernard
#  + FLEX_Golden_Tate + FLEX_Greg_Olsen + FLEX_Isaiah_Crowell + FLEX_JJ_Nelson
#  + FLEX_Jack_Doyle + FLEX_Jakeem_Grant + FLEX_Jalen_Richard
#  + FLEX_Jamaal_Williams + FLEX_James_Conner + FLEX_James_Washington
#  + FLEX_James_White + FLEX_Jamison_Crowder + FLEX_Jared_Cook
#  + FLEX_Jaron_Brown + FLEX_Jarvis_Landry + FLEX_Javorius_Allen
#  + FLEX_Jay_Ajayi + FLEX_Jaylen_Samuels + FLEX_Jeremy_Hill
#  + FLEX_Jeremy_Kerley + FLEX_Jesse_James + FLEX_Jimmy_Graham + FLEX_Joe_Mixon
#  + FLEX_John_Brown + FLEX_John_Ross + FLEX_Jordan_Howard + FLEX_Jordan_Reed
#  + FLEX_Jordan_Wilkins + FLEX_Jordy_Nelson + FLEX_Josh_Doctson
#  + FLEX_Josh_Gordon + FLEX_JuJu_Smith_Schuster + FLEX_Julio_Jones
#  + FLEX_Kareem_Hunt + FLEX_Keelan_Cole + FLEX_Keenan_Allen
#  + FLEX_Kelvin_Benjamin + FLEX_Kenneth_Dixon + FLEX_Kenny_Golladay
#  + FLEX_Kenny_Stills + FLEX_Kenyan_Drake + FLEX_Kerryon_Johnson
#  + FLEX_Kevin_White + FLEX_Kyle_Juszczyk + FLEX_Kyle_Rudolph
#  + FLEX_Lamar_Miller + FLEX_Laquon_Treadwell + FLEX_Larry_Fitzgerald
#  + FLEX_Latavius_Murray + FLEX_LeGarrette_Blount + FLEX_LeSean_McCoy
#  + FLEX_Leonard_Fournette + FLEX_Luke_Willson + FLEX_Marquise_Goodwin
#  + FLEX_Marshawn_Lynch + FLEX_Marvin_Jones + FLEX_Matt_Breida
#  + FLEX_Melvin_Gordon + FLEX_Michael_Crabtree + FLEX_Michael_Gallup
#  + FLEX_Michael_Thomas + FLEX_Mike_Evans + FLEX_Mike_Gesicki
#  + FLEX_Mike_Gillislee + FLEX_Mike_Wallace + FLEX_Mike_Williams
#  + FLEX_Mohamed_Sanu + FLEX_Nelson_Agholor + FLEX_Nick_Vannett
#  + FLEX_Nyheim_Hines + FLEX_OJ_Howard + FLEX_Odell_Beckham_Jr
#  + FLEX_Paul_Richardson + FLEX_Peyton_Barber + FLEX_Phillip_Dorsett
#  + FLEX_Pierre_Garcon + FLEX_Quincy_Enunwa + FLEX_Randall_Cobb
#  + FLEX_Rashaad_Penny + FLEX_Rex_Burkhead + FLEX_Ricky_Seals_Jones
#  + FLEX_Rishard_Matthews + FLEX_Rob_Gronkowski + FLEX_Robby_Anderson
#  + FLEX_Robert_Woods + FLEX_Royce_Freeman + FLEX_Ryan_Grant
#  + FLEX_Ryan_Griffin + FLEX_Sammy_Watkins + FLEX_Saquon_Barkley
#  + FLEX_Seth_Roberts + FLEX_Spencer_Ware + FLEX_Stefon_Diggs
#  + FLEX_Sterling_Shepard + FLEX_T.Y._Hilton + FLEX_TJ_Yeldon
#  + FLEX_Tarik_Cohen + FLEX_Taylor_Gabriel + FLEX_Taywan_Taylor + FLEX_Ted_Ginn
#  + FLEX_Terrance_Williams + FLEX_Terrelle_Pryor + FLEX_Tevin_Coleman
#  + FLEX_Theo_Riddick + FLEX_Todd_Gurley + FLEX_Torrey_Smith
#  + FLEX_Travis_Benjamin + FLEX_Travis_Kelce + FLEX_Tre'Quan_Smith
#  + FLEX_Trent_Taylor + FLEX_Trey_Burton + FLEX_Ty_Montgomery + FLEX_Tyler_Boyd
#  + FLEX_Tyler_Eifert + FLEX_Tyler_Higbee + FLEX_Tyler_Lockett
#  + FLEX_Tyreek_Hill + FLEX_Tyrell_Williams + FLEX_Vernon_Davis
#  + FLEX_Willie_Snead + FLEX_Zach_Ertz + FLEX_Zay_Jones = 1
#
# _C8: FLEX_Antonio_Brown + WR_Antonio_Brown <= 1
#
# _C9: FLEX_DeAndre_Hopkins + WR_DeAndre_Hopkins <= 1
#
# _C10: FLEX_Michael_Thomas + WR_Michael_Thomas <= 1
#
# _C11: FLEX_Julio_Jones + WR_Julio_Jones <= 1
#
# _C12: FLEX_Keenan_Allen + WR_Keenan_Allen <= 1
#
# _C13: FLEX_AJ_Green + WR_AJ_Green <= 1
#
# _C14: FLEX_Davante_Adams + WR_Davante_Adams <= 1
#
# _C15: FLEX_Stefon_Diggs + WR_Stefon_Diggs <= 1
#
# _C16: FLEX_Tyreek_Hill + WR_Tyreek_Hill <= 1
#
# _C17: FLEX_Adam_Thielen + WR_Adam_Thielen <= 1
#
# _C18: FLEX_T.Y._Hilton + WR_T.Y._Hilton <= 1
#
# _C19: FLEX_Chris_Hogan + WR_Chris_Hogan <= 1
#
# _C20: FLEX_Larry_Fitzgerald + WR_Larry_Fitzgerald <= 1
#
# _C21: FLEX_Odell_Beckham_Jr + WR_Odell_Beckham_Jr <= 1
#
# _C22: FLEX_Golden_Tate + WR_Golden_Tate <= 1
#
# _C23: FLEX_Mike_Evans + WR_Mike_Evans <= 1
#
# _C24: FLEX_Demaryius_Thomas + WR_Demaryius_Thomas <= 1
#
# _C25: FLEX_Marvin_Jones + WR_Marvin_Jones <= 1
#
# _C26: FLEX_Jarvis_Landry + WR_Jarvis_Landry <= 1
#
# _C27: FLEX_Amari_Cooper + WR_Amari_Cooper <= 1
#
# _C28: FLEX_Doug_Baldwin + WR_Doug_Baldwin <= 1
#
# _C29: FLEX_Brandin_Cooks + WR_Brandin_Cooks <= 1
#
# _C30: FLEX_Nelson_Agholor + WR_Nelson_Agholor <= 1
#
# _C31: FLEX_JuJu_Smith_Schuster + WR_JuJu_Smith_Schuster <= 1
#
# _C32: FLEX_Michael_Crabtree + WR_Michael_Crabtree <= 1
#
# _C33: FLEX_Kenny_Stills + WR_Kenny_Stills <= 1
#
# _C34: FLEX_Allen_Robinson + WR_Allen_Robinson <= 1
#
# _C35: FLEX_Emmanuel_Sanders + WR_Emmanuel_Sanders <= 1
#
# _C36: FLEX_Cooper_Kupp + WR_Cooper_Kupp <= 1
#
# _C37: FLEX_Robby_Anderson + WR_Robby_Anderson <= 1
#
# _C38: FLEX_Robert_Woods + WR_Robert_Woods <= 1
#
# _C39: FLEX_Corey_Davis + WR_Corey_Davis <= 1
#
# _C40: FLEX_Devin_Funchess + WR_Devin_Funchess <= 1
#
# _C41: FLEX_Randall_Cobb + WR_Randall_Cobb <= 1
#
# _C42: FLEX_Jamison_Crowder + WR_Jamison_Crowder <= 1
#
# _C43: FLEX_Marquise_Goodwin + WR_Marquise_Goodwin <= 1
#
# _C44: FLEX_Sterling_Shepard + WR_Sterling_Shepard <= 1
#
# _C45: FLEX_Keelan_Cole + WR_Keelan_Cole <= 1
#
# _C46: FLEX_Pierre_Garcon + WR_Pierre_Garcon <= 1
#
# _C47: FLEX_Jordy_Nelson + WR_Jordy_Nelson <= 1
#
# _C48: FLEX_Josh_Gordon + WR_Josh_Gordon <= 1
#
# _C49: FLEX_Ted_Ginn + WR_Ted_Ginn <= 1
#
# _C50: FLEX_Kelvin_Benjamin + WR_Kelvin_Benjamin <= 1
#
# _C51: FLEX_Mohamed_Sanu + WR_Mohamed_Sanu <= 1
#
# _C52: FLEX_Sammy_Watkins + WR_Sammy_Watkins <= 1
#
# _C53: FLEX_Kenny_Golladay + WR_Kenny_Golladay <= 1
#
# _C54: FLEX_DeSean_Jackson + WR_DeSean_Jackson <= 1
#
# _C55: FLEX_Quincy_Enunwa + WR_Quincy_Enunwa <= 1
#
# _C56: FLEX_Tyrell_Williams + WR_Tyrell_Williams <= 1
#
# _C57: FLEX_Danny_Amendola + WR_Danny_Amendola <= 1
#
# _C58: FLEX_Tyler_Lockett + WR_Tyler_Lockett <= 1
#
# _C59: FLEX_Allen_Hurns + WR_Allen_Hurns <= 1
#
# _C60: FLEX_Dede_Westbrook + WR_Dede_Westbrook <= 1
#
# _C61: FLEX_Josh_Doctson + WR_Josh_Doctson <= 1
#
# _C62: FLEX_John_Brown + WR_John_Brown <= 1
#
# _C63: FLEX_Paul_Richardson + WR_Paul_Richardson <= 1
#
# _C64: FLEX_John_Ross + WR_John_Ross <= 1
#
# _C65: FLEX_Albert_Wilson + WR_Albert_Wilson <= 1
#
# _C66: FLEX_Mike_Wallace + WR_Mike_Wallace <= 1
#
# _C67: FLEX_Donte_Moncrief + WR_Donte_Moncrief <= 1
#
# _C68: FLEX_Rishard_Matthews + WR_Rishard_Matthews <= 1
#
# _C69: FLEX_Chris_Godwin + WR_Chris_Godwin <= 1
#
# _C70: FLEX_Ryan_Grant + WR_Ryan_Grant <= 1
#
# _C71: FLEX_Anthony_Miller + WR_Anthony_Miller <= 1
#
# _C72: FLEX_Michael_Gallup + WR_Michael_Gallup <= 1
#
# _C73: FLEX_Calvin_Ridley + WR_Calvin_Ridley <= 1
#
# _C74: FLEX_Bruce_Ellington + WR_Bruce_Ellington <= 1
#
# _C75: FLEX_Mike_Williams + WR_Mike_Williams <= 1
#
# _C76: FLEX_Phillip_Dorsett + WR_Phillip_Dorsett <= 1
#
# _C77: FLEX_Terrance_Williams + WR_Terrance_Williams <= 1
#
# _C78: FLEX_Taywan_Taylor + WR_Taywan_Taylor <= 1
#
# _C79: FLEX_Courtland_Sutton + WR_Courtland_Sutton <= 1
#
# _C80: FLEX_D.J._Moore + WR_D.J._Moore <= 1
#
# _C81: FLEX_Geronimo_Allison + WR_Geronimo_Allison <= 1
#
# _C82: FLEX_Terrelle_Pryor + WR_Terrelle_Pryor <= 1
#
# _C83: FLEX_Christian_Kirk + WR_Christian_Kirk <= 1
#
# _C84: FLEX_James_Washington + WR_James_Washington <= 1
#
# _C85: FLEX_Travis_Benjamin + WR_Travis_Benjamin <= 1
#
# _C86: FLEX_Austin_Carr + WR_Austin_Carr <= 1
#
# _C87: FLEX_Chad_Williams + WR_Chad_Williams <= 1
#
# _C88: FLEX_Antonio_Callaway + WR_Antonio_Callaway <= 1
#
# _C89: FLEX_Adam_Humphries + WR_Adam_Humphries <= 1
#
# _C90: FLEX_Cole_Beasley + WR_Cole_Beasley <= 1
#
# _C91: FLEX_Taylor_Gabriel + WR_Taylor_Gabriel <= 1
#
# _C92: FLEX_Tyler_Boyd + WR_Tyler_Boyd <= 1
#
# _C93: FLEX_Chester_Rogers + WR_Chester_Rogers <= 1
#
# _C94: FLEX_Willie_Snead + WR_Willie_Snead <= 1
#
# _C95: FLEX_Trent_Taylor + WR_Trent_Taylor <= 1
#
# _C96: FLEX_Brandon_Marshall + WR_Brandon_Marshall <= 1
#
# _C97: FLEX_JJ_Nelson + WR_JJ_Nelson <= 1
#
# _C98: FLEX_Seth_Roberts + WR_Seth_Roberts <= 1
#
# _C99: FLEX_Torrey_Smith + WR_Torrey_Smith <= 1
#
# _C100: FLEX_Cordarrelle_Patterson + WR_Cordarrelle_Patterson <= 1
#
# _C101: FLEX_Zay_Jones + WR_Zay_Jones <= 1
#
# _C102: FLEX_Laquon_Treadwell + WR_Laquon_Treadwell <= 1
#
# _C103: FLEX_Tre'Quan_Smith + WR_Tre'Quan_Smith <= 1
#
# _C104: FLEX_Chris_Conley + WR_Chris_Conley <= 1
#
# _C105: FLEX_Cody_Latimer + WR_Cody_Latimer <= 1
#
# _C106: FLEX_Jeremy_Kerley + WR_Jeremy_Kerley <= 1
#
# _C107: FLEX_Jaron_Brown + WR_Jaron_Brown <= 1
#
# _C108: FLEX_Kevin_White + WR_Kevin_White <= 1
#
# _C109: FLEX_D.J._Chark + WR_D.J._Chark <= 1
#
# _C110: FLEX_Jakeem_Grant + WR_Jakeem_Grant <= 1
#
# _C111: FLEX_Todd_Gurley + RB_Todd_Gurley <= 1
#
# _C112: FLEX_Alvin_Kamara + RB_Alvin_Kamara <= 1
#
# _C113: FLEX_David_Johnson + RB_David_Johnson <= 1
#
# _C114: FLEX_Ezekiel_Elliott + RB_Ezekiel_Elliott <= 1
#
# _C115: FLEX_Melvin_Gordon + RB_Melvin_Gordon <= 1
#
# _C116: FLEX_Leonard_Fournette + RB_Leonard_Fournette <= 1
#
# _C117: FLEX_Kareem_Hunt + RB_Kareem_Hunt <= 1
#
# _C118: FLEX_Christian_McCaffrey + RB_Christian_McCaffrey <= 1
#
# _C119: FLEX_Saquon_Barkley + RB_Saquon_Barkley <= 1
#
# _C120: FLEX_Dalvin_Cook + RB_Dalvin_Cook <= 1
#
# _C121: FLEX_Devonta_Freeman + RB_Devonta_Freeman <= 1
#
# _C122: FLEX_James_Conner + RB_James_Conner <= 1
#
# _C123: FLEX_Alex_Collins + RB_Alex_Collins <= 1
#
# _C124: FLEX_Joe_Mixon + RB_Joe_Mixon <= 1
#
# _C125: FLEX_LeSean_McCoy + RB_LeSean_McCoy <= 1
#
# _C126: FLEX_Lamar_Miller + RB_Lamar_Miller <= 1
#
# _C127: FLEX_Kenyan_Drake + RB_Kenyan_Drake <= 1
#
# _C128: FLEX_Jordan_Howard + RB_Jordan_Howard <= 1
#
# _C129: FLEX_Jamaal_Williams + RB_Jamaal_Williams <= 1
#
# _C130: FLEX_Rex_Burkhead + RB_Rex_Burkhead <= 1
#
# _C131: FLEX_Derrick_Henry + RB_Derrick_Henry <= 1
#
# _C132: FLEX_Royce_Freeman + RB_Royce_Freeman <= 1
#
# _C133: FLEX_Jay_Ajayi + RB_Jay_Ajayi <= 1
#
# _C134: FLEX_Carlos_Hyde + RB_Carlos_Hyde <= 1
#
# _C135: FLEX_Marshawn_Lynch + RB_Marshawn_Lynch <= 1
#
# _C136: FLEX_Dion_Lewis + RB_Dion_Lewis <= 1
#
# _C137: FLEX_Peyton_Barber + RB_Peyton_Barber <= 1
#
# _C138: FLEX_Kerryon_Johnson + RB_Kerryon_Johnson <= 1
#
# _C139: FLEX_Bilal_Powell + RB_Bilal_Powell <= 1
#
# _C140: FLEX_Chris_Thompson + RB_Chris_Thompson <= 1
#
# _C141: FLEX_James_White + RB_James_White <= 1
#
# _C142: FLEX_Isaiah_Crowell + RB_Isaiah_Crowell <= 1
#
# _C143: FLEX_Tevin_Coleman + RB_Tevin_Coleman <= 1
#
# _C144: FLEX_Chris_Carson + RB_Chris_Carson <= 1
#
# _C145: FLEX_Duke_Johnson + RB_Duke_Johnson <= 1
#
# _C146: FLEX_Matt_Breida + RB_Matt_Breida <= 1
#
# _C147: FLEX_Jordan_Wilkins + RB_Jordan_Wilkins <= 1
#
# _C148: FLEX_Ty_Montgomery + RB_Ty_Montgomery <= 1
#
# _C149: FLEX_Tarik_Cohen + RB_Tarik_Cohen <= 1
#
# _C150: FLEX_Adrian_Peterson + RB_Adrian_Peterson <= 1
#
# _C151: FLEX_Giovani_Bernard + RB_Giovani_Bernard <= 1
#
# _C152: FLEX_Alfred_Morris + RB_Alfred_Morris <= 1
#
# _C153: FLEX_Theo_Riddick + RB_Theo_Riddick <= 1
#
# _C154: FLEX_Javorius_Allen + RB_Javorius_Allen <= 1
#
# _C155: FLEX_Devontae_Booker + RB_Devontae_Booker <= 1
#
# _C156: FLEX_Corey_Clement + RB_Corey_Clement <= 1
#
# _C157: FLEX_Latavius_Murray + RB_Latavius_Murray <= 1
#
# _C158: FLEX_Darren_Sproles + RB_Darren_Sproles <= 1
#
# _C159: FLEX_Austin_Ekeler + RB_Austin_Ekeler <= 1
#
# _C160: FLEX_Mike_Gillislee + RB_Mike_Gillislee <= 1
#
# _C161: FLEX_CJ_Anderson + RB_CJ_Anderson <= 1
#
# _C162: FLEX_Frank_Gore + RB_Frank_Gore <= 1
#
# _C163: FLEX_Nyheim_Hines + RB_Nyheim_Hines <= 1
#
# _C164: FLEX_Jaylen_Samuels + RB_Jaylen_Samuels <= 1
#
# _C165: FLEX_LeGarrette_Blount + RB_LeGarrette_Blount <= 1
#
# _C166: FLEX_Jeremy_Hill + RB_Jeremy_Hill <= 1
#
# _C167: FLEX_Rashaad_Penny + RB_Rashaad_Penny <= 1
#
# _C168: FLEX_Doug_Martin + RB_Doug_Martin <= 1
#
# _C169: FLEX_TJ_Yeldon + RB_TJ_Yeldon <= 1
#
# _C170: FLEX_Alfred_Blue + RB_Alfred_Blue <= 1
#
# _C171: FLEX_Spencer_Ware + RB_Spencer_Ware <= 1
#
# _C172: FLEX_Kenneth_Dixon + RB_Kenneth_Dixon <= 1
#
# _C173: FLEX_Chase_Edmonds + RB_Chase_Edmonds <= 1
#
# _C174: FLEX_Jalen_Richard + RB_Jalen_Richard <= 1
#
# _C175: FLEX_Chris_Ivory + RB_Chris_Ivory <= 1
#
# _C176: FLEX_Kyle_Juszczyk + RB_Kyle_Juszczyk <= 1
#
# _C177: FLEX_Christine_Michael + RB_Christine_Michael <= 1
#
# _C178: FLEX_Corey_Grant + RB_Corey_Grant <= 1
#
# _C179: FLEX_Rob_Gronkowski + TE_Rob_Gronkowski <= 1
#
# _C180: FLEX_Travis_Kelce + TE_Travis_Kelce <= 1
#
# _C181: FLEX_Zach_Ertz + TE_Zach_Ertz <= 1
#
# _C182: FLEX_Delanie_Walker + TE_Delanie_Walker <= 1
#
# _C183: FLEX_Greg_Olsen + TE_Greg_Olsen <= 1
#
# _C184: FLEX_Kyle_Rudolph + TE_Kyle_Rudolph <= 1
#
# _C185: FLEX_Jimmy_Graham + TE_Jimmy_Graham <= 1
#
# _C186: FLEX_Trey_Burton + TE_Trey_Burton <= 1
#
# _C187: FLEX_Jack_Doyle + TE_Jack_Doyle <= 1
#
# _C188: FLEX_Evan_Engram + TE_Evan_Engram <= 1
#
# _C189: FLEX_Jordan_Reed + TE_Jordan_Reed <= 1
#
# _C190: FLEX_Tyler_Eifert + TE_Tyler_Eifert <= 1
#
# _C191: FLEX_Jared_Cook + TE_Jared_Cook <= 1
#
# _C192: FLEX_Ricky_Seals_Jones + TE_Ricky_Seals_Jones <= 1
#
# _C193: FLEX_George_Kittle + TE_George_Kittle <= 1
#
# _C194: FLEX_Charles_Clay + TE_Charles_Clay <= 1
#
# _C195: FLEX_David_Njoku + TE_David_Njoku <= 1
#
# _C196: FLEX_Benjamin_Watson + TE_Benjamin_Watson <= 1
#
# _C197: FLEX_Austin_Seferian_Jenkins + TE_Austin_Seferian_Jenkins <= 1
#
# _C198: FLEX_Cameron_Brate + TE_Cameron_Brate <= 1
#
# _C199: FLEX_OJ_Howard + TE_OJ_Howard <= 1
#
# _C200: FLEX_Mike_Gesicki + TE_Mike_Gesicki <= 1
#
# _C201: FLEX_Eric_Ebron + TE_Eric_Ebron <= 1
#
# _C202: FLEX_Austin_Hooper + TE_Austin_Hooper <= 1
#
# _C203: FLEX_Jesse_James + TE_Jesse_James <= 1
#
# _C204: FLEX_Ryan_Griffin + TE_Ryan_Griffin <= 1
#
# _C205: FLEX_Antonio_Gates + TE_Antonio_Gates <= 1
#
# _C206: FLEX_Dallas_Goedert + TE_Dallas_Goedert <= 1
#
# _C207: FLEX_Nick_Vannett + TE_Nick_Vannett <= 1
#
# _C208: FLEX_Luke_Willson + TE_Luke_Willson <= 1
#
# _C209: FLEX_Vernon_Davis + TE_Vernon_Davis <= 1
#
# _C210: FLEX_Tyler_Higbee + TE_Tyler_Higbee <= 1
#
# _C211: FLEX_Blake_Jarwin + TE_Blake_Jarwin <= 1
#
# _C212: 4100 DST_Arizona_Cardinals + 3300 DST_Atlanta_Falcons
#  + 4800 DST_Baltimore_Ravens + 4500 DST_Buffalo_Bills
#  + 4300 DST_Carolina_Panthers + 3600 DST_Chicago_Bears
#  + 4400 DST_Cincinnati_Bengals + 3000 DST_Cleveland_Browns
#  + 3500 DST_Dallas_Cowboys + 4600 DST_Denver_Broncos + 4700 DST_Detroit_Lions
#  + 4100 DST_Green_Bay_Packers + 4000 DST_Houston_Texans
#  + 3900 DST_Indianapolis_Colts + 4700 DST_Jacksonville_Jaguars
#  + 3900 DST_Kansas_City_Chiefs + 4300 DST_Los_Angeles_Chargers
#  + 5000 DST_Los_Angeles_Rams + 3200 DST_Miami_Dolphins
#  + 4500 DST_Minnesota_Vikings + 4200 DST_New_England_Patriots
#  + 4600 DST_New_Orleans_Saints + 3900 DST_New_York_Giants
#  + 3500 DST_New_York_Jets + 4100 DST_Oakland_Raiders
#  + 4500 DST_Philadelphia_Eagles + 4200 DST_Pittsburgh_Steelers
#  + 3800 DST_San_Francisco_49ers + 4100 DST_Seattle_Seahawks
#  + 3400 DST_Tampa_Bay_Buccaneers + 4200 DST_Tennessee_Titans
#  + 4000 DST_Washington_Redskins + 8400 FLEX_AJ_Green
#  + 4600 FLEX_Adam_Humphries + 7600 FLEX_Adam_Thielen
#  + 6300 FLEX_Adrian_Peterson + 5000 FLEX_Albert_Wilson
#  + 6700 FLEX_Alex_Collins + 5000 FLEX_Alfred_Blue + 5500 FLEX_Alfred_Morris
#  + 5900 FLEX_Allen_Hurns + 6500 FLEX_Allen_Robinson + 8700 FLEX_Alvin_Kamara
#  + 7400 FLEX_Amari_Cooper + 5400 FLEX_Anthony_Miller + 9000 FLEX_Antonio_Brown
#  + 4500 FLEX_Antonio_Callaway + 4800 FLEX_Antonio_Gates
#  + 4500 FLEX_Austin_Carr + 5100 FLEX_Austin_Ekeler + 4800 FLEX_Austin_Hooper
#  + 4600 FLEX_Austin_Seferian_Jenkins + 4900 FLEX_Benjamin_Watson
#  + 6000 FLEX_Bilal_Powell + 4000 FLEX_Blake_Jarwin + 7600 FLEX_Brandin_Cooks
#  + 5200 FLEX_Brandon_Marshall + 4600 FLEX_Bruce_Ellington
#  + 5700 FLEX_CJ_Anderson + 5600 FLEX_Calvin_Ridley + 5400 FLEX_Cameron_Brate
#  + 5900 FLEX_Carlos_Hyde + 4500 FLEX_Chad_Williams + 5200 FLEX_Charles_Clay
#  + 5000 FLEX_Chase_Edmonds + 4900 FLEX_Chester_Rogers + 5900 FLEX_Chris_Carson
#  + 4500 FLEX_Chris_Conley + 5500 FLEX_Chris_Godwin + 6700 FLEX_Chris_Hogan
#  + 5700 FLEX_Chris_Ivory + 6200 FLEX_Chris_Thompson + 5400 FLEX_Christian_Kirk
#  + 7500 FLEX_Christian_McCaffrey + 4700 FLEX_Christine_Michael
#  + 4500 FLEX_Cody_Latimer + 4800 FLEX_Cole_Beasley + 6500 FLEX_Cooper_Kupp
#  + 4600 FLEX_Cordarrelle_Patterson + 5000 FLEX_Corey_Clement
#  + 6400 FLEX_Corey_Davis + 4500 FLEX_Corey_Grant + 4700 FLEX_Courtland_Sutton
#  + 4500 FLEX_D.J._Chark + 4800 FLEX_D.J._Moore + 4000 FLEX_Dallas_Goedert
#  + 7300 FLEX_Dalvin_Cook + 5100 FLEX_Danny_Amendola + 4600 FLEX_Darren_Sproles
#  + 8100 FLEX_Davante_Adams + 8600 FLEX_David_Johnson + 5300 FLEX_David_Njoku
#  + 8800 FLEX_DeAndre_Hopkins + 5900 FLEX_DeSean_Jackson
#  + 5300 FLEX_Dede_Westbrook + 6100 FLEX_Delanie_Walker
#  + 7000 FLEX_Demaryius_Thomas + 6800 FLEX_Derrick_Henry
#  + 6400 FLEX_Devin_Funchess + 7100 FLEX_Devonta_Freeman
#  + 6000 FLEX_Devontae_Booker + 6200 FLEX_Dion_Lewis + 5200 FLEX_Donte_Moncrief
#  + 7500 FLEX_Doug_Baldwin + 5500 FLEX_Doug_Martin + 5800 FLEX_Duke_Johnson
#  + 6300 FLEX_Emmanuel_Sanders + 5000 FLEX_Eric_Ebron + 6000 FLEX_Evan_Engram
#  + 8300 FLEX_Ezekiel_Elliott + 5300 FLEX_Frank_Gore + 5300 FLEX_George_Kittle
#  + 5000 FLEX_Geronimo_Allison + 5400 FLEX_Giovani_Bernard
#  + 7700 FLEX_Golden_Tate + 6300 FLEX_Greg_Olsen + 6500 FLEX_Isaiah_Crowell
#  + 4600 FLEX_JJ_Nelson + 5600 FLEX_Jack_Doyle + 4500 FLEX_Jakeem_Grant
#  + 4600 FLEX_Jalen_Richard + 6100 FLEX_Jamaal_Williams
#  + 5000 FLEX_James_Conner + 5100 FLEX_James_Washington + 5500 FLEX_James_White
#  + 6200 FLEX_Jamison_Crowder + 6000 FLEX_Jared_Cook + 4500 FLEX_Jaron_Brown
#  + 6600 FLEX_Jarvis_Landry + 4900 FLEX_Javorius_Allen + 6400 FLEX_Jay_Ajayi
#  + 4500 FLEX_Jaylen_Samuels + 4600 FLEX_Jeremy_Hill + 4900 FLEX_Jeremy_Kerley
#  + 4600 FLEX_Jesse_James + 6000 FLEX_Jimmy_Graham + 6900 FLEX_Joe_Mixon
#  + 5500 FLEX_John_Brown + 5100 FLEX_John_Ross + 7400 FLEX_Jordan_Howard
#  + 5800 FLEX_Jordan_Reed + 5100 FLEX_Jordan_Wilkins + 6300 FLEX_Jordy_Nelson
#  + 5700 FLEX_Josh_Doctson + 6900 FLEX_Josh_Gordon
#  + 7000 FLEX_JuJu_Smith_Schuster + 8300 FLEX_Julio_Jones
#  + 8000 FLEX_Kareem_Hunt + 4500 FLEX_Keelan_Cole + 8000 FLEX_Keenan_Allen
#  + 5800 FLEX_Kelvin_Benjamin + 5300 FLEX_Kenneth_Dixon
#  + 6100 FLEX_Kenny_Golladay + 6000 FLEX_Kenny_Stills + 6600 FLEX_Kenyan_Drake
#  + 6500 FLEX_Kerryon_Johnson + 4500 FLEX_Kevin_White + 4500 FLEX_Kyle_Juszczyk
#  + 5900 FLEX_Kyle_Rudolph + 6500 FLEX_Lamar_Miller
#  + 4600 FLEX_Laquon_Treadwell + 7300 FLEX_Larry_Fitzgerald
#  + 5500 FLEX_Latavius_Murray + 5700 FLEX_LeGarrette_Blount
#  + 7300 FLEX_LeSean_McCoy + 8000 FLEX_Leonard_Fournette
#  + 5500 FLEX_Luke_Willson + 6400 FLEX_Marquise_Goodwin
#  + 7400 FLEX_Marshawn_Lynch + 7500 FLEX_Marvin_Jones + 5000 FLEX_Matt_Breida
#  + 8100 FLEX_Melvin_Gordon + 6600 FLEX_Michael_Crabtree
#  + 5500 FLEX_Michael_Gallup + 8500 FLEX_Michael_Thomas + 7700 FLEX_Mike_Evans
#  + 4700 FLEX_Mike_Gesicki + 4600 FLEX_Mike_Gillislee + 5300 FLEX_Mike_Wallace
#  + 5400 FLEX_Mike_Williams + 5900 FLEX_Mohamed_Sanu + 5900 FLEX_Nelson_Agholor
#  + 4300 FLEX_Nick_Vannett + 5400 FLEX_Nyheim_Hines + 5400 FLEX_OJ_Howard
#  + 7800 FLEX_Odell_Beckham_Jr + 5700 FLEX_Paul_Richardson
#  + 5600 FLEX_Peyton_Barber + 5900 FLEX_Phillip_Dorsett
#  + 6200 FLEX_Pierre_Garcon + 5400 FLEX_Quincy_Enunwa + 6200 FLEX_Randall_Cobb
#  + 6300 FLEX_Rashaad_Penny + 6300 FLEX_Rex_Burkhead
#  + 5100 FLEX_Ricky_Seals_Jones + 6000 FLEX_Rishard_Matthews
#  + 7900 FLEX_Rob_Gronkowski + 6600 FLEX_Robby_Anderson
#  + 6800 FLEX_Robert_Woods + 6000 FLEX_Royce_Freeman + 4900 FLEX_Ryan_Grant
#  + 4700 FLEX_Ryan_Griffin + 6500 FLEX_Sammy_Watkins + 7600 FLEX_Saquon_Barkley
#  + 4500 FLEX_Seth_Roberts + 5200 FLEX_Spencer_Ware + 7400 FLEX_Stefon_Diggs
#  + 6000 FLEX_Sterling_Shepard + 7200 FLEX_T.Y._Hilton + 5000 FLEX_TJ_Yeldon
#  + 5600 FLEX_Tarik_Cohen + 5000 FLEX_Taylor_Gabriel + 4500 FLEX_Taywan_Taylor
#  + 6200 FLEX_Ted_Ginn + 5300 FLEX_Terrance_Williams + 5600 FLEX_Terrelle_Pryor
#  + 5900 FLEX_Tevin_Coleman + 5400 FLEX_Theo_Riddick + 9200 FLEX_Todd_Gurley
#  + 4900 FLEX_Torrey_Smith + 4800 FLEX_Travis_Benjamin + 7100 FLEX_Travis_Kelce
#  + 4500 FLEX_Tre'Quan_Smith + 4500 FLEX_Trent_Taylor + 5700 FLEX_Trey_Burton
#  + 5700 FLEX_Ty_Montgomery + 4700 FLEX_Tyler_Boyd + 5500 FLEX_Tyler_Eifert
#  + 5300 FLEX_Tyler_Higbee + 5600 FLEX_Tyler_Lockett + 7300 FLEX_Tyreek_Hill
#  + 5500 FLEX_Tyrell_Williams + 4500 FLEX_Vernon_Davis + 5100 FLEX_Willie_Snead
#  + 6600 FLEX_Zach_Ertz + 5300 FLEX_Zay_Jones + 4500 K_Adam_Vinatieri
#  + 3650 K_Aldrick_Rosas + 4450 K_Brandon_McManus + 3500 K_Brett_Maher
#  + 4600 K_Caleb_Sturgis + 4200 K_Chandler_Catanzaro + 4400 K_Chris_Boswell
#  + 3950 K_Cody_Parkey + 4700 K_Daniel_Carlson + 4250 K_Dustin_Hopkins
#  + 4550 K_Graham_Gano + 4950 K_Greg_Zuerlein + 3850 K_Harrison_Butker
#  + 4750 K_Jake_Elliott + 3450 K_Jason_Myers + 3700 K_Jason_Sanders
#  + 4000 K_Josh_Lambo + 4800 K_Justin_Tucker + 4350 K_Ka'imi_Fairbairn
#  + 4650 K_Mason_Crosby + 4100 K_Matt_Bryant + 4900 K_Matt_Prater
#  + 3750 K_Mike_Nugent + 4300 K_Phil_Dawson + 3900 K_Randy_Bullock
#  + 4150 K_Robbie_Gould + 4050 K_Ryan_Succop + 3800 K_Sebastian_Janikowski
#  + 5000 K_Stephen_Gostkowski + 3550 K_Steven_Hauschka + 4850 K_Wil_Lutz
#  + 3600 K_Zane_Gonzalez + 8700 QB_Aaron_Rodgers + 6900 QB_Alex_Smith
#  + 7300 QB_Andrew_Luck + 6800 QB_Andy_Dalton + 8000 QB_Ben_Roethlisberger
#  + 6600 QB_Blake_Bortles + 8100 QB_Cam_Newton + 6300 QB_Case_Keenum
#  + 7000 QB_Dak_Prescott + 7400 QB_Derek_Carr + 8200 QB_Deshaun_Watson
#  + 8400 QB_Drew_Brees + 6300 QB_Eli_Manning + 8000 QB_Jared_Goff
#  + 7100 QB_Jimmy_Garoppolo + 6100 QB_Joe_Flacco + 7600 QB_Kirk_Cousins
#  + 7200 QB_Marcus_Mariota + 7000 QB_Matt_Ryan + 8400 QB_Matthew_Stafford
#  + 6500 QB_Mitch_Trubisky + 6000 QB_Nathan_Peterman + 7400 QB_Nick_Foles
#  + 6700 QB_Patrick_Mahomes + 7500 QB_Philip_Rivers + 7900 QB_Russell_Wilson
#  + 6200 QB_Ryan_Fitzpatrick + 6200 QB_Ryan_Tannehill + 6400 QB_Sam_Bradford
#  + 6800 QB_Sam_Darnold + 8600 QB_Tom_Brady + 6600 QB_Tyrod_Taylor
#  + 6300 RB_Adrian_Peterson + 6700 RB_Alex_Collins + 5000 RB_Alfred_Blue
#  + 5500 RB_Alfred_Morris + 8700 RB_Alvin_Kamara + 5100 RB_Austin_Ekeler
#  + 6000 RB_Bilal_Powell + 5700 RB_CJ_Anderson + 5900 RB_Carlos_Hyde
#  + 5000 RB_Chase_Edmonds + 5900 RB_Chris_Carson + 5700 RB_Chris_Ivory
#  + 6200 RB_Chris_Thompson + 7500 RB_Christian_McCaffrey
#  + 4700 RB_Christine_Michael + 5000 RB_Corey_Clement + 4500 RB_Corey_Grant
#  + 7300 RB_Dalvin_Cook + 4600 RB_Darren_Sproles + 8600 RB_David_Johnson
#  + 6800 RB_Derrick_Henry + 7100 RB_Devonta_Freeman + 6000 RB_Devontae_Booker
#  + 6200 RB_Dion_Lewis + 5500 RB_Doug_Martin + 5800 RB_Duke_Johnson
#  + 8300 RB_Ezekiel_Elliott + 5300 RB_Frank_Gore + 5400 RB_Giovani_Bernard
#  + 6500 RB_Isaiah_Crowell + 4600 RB_Jalen_Richard + 6100 RB_Jamaal_Williams
#  + 5000 RB_James_Conner + 5500 RB_James_White + 4900 RB_Javorius_Allen
#  + 6400 RB_Jay_Ajayi + 4500 RB_Jaylen_Samuels + 4600 RB_Jeremy_Hill
#  + 6900 RB_Joe_Mixon + 7400 RB_Jordan_Howard + 5100 RB_Jordan_Wilkins
#  + 8000 RB_Kareem_Hunt + 5300 RB_Kenneth_Dixon + 6600 RB_Kenyan_Drake
#  + 6500 RB_Kerryon_Johnson + 4500 RB_Kyle_Juszczyk + 6500 RB_Lamar_Miller
#  + 5500 RB_Latavius_Murray + 5700 RB_LeGarrette_Blount + 7300 RB_LeSean_McCoy
#  + 8000 RB_Leonard_Fournette + 7400 RB_Marshawn_Lynch + 5000 RB_Matt_Breida
#  + 8100 RB_Melvin_Gordon + 4600 RB_Mike_Gillislee + 5400 RB_Nyheim_Hines
#  + 5600 RB_Peyton_Barber + 6300 RB_Rashaad_Penny + 6300 RB_Rex_Burkhead
#  + 6000 RB_Royce_Freeman + 7600 RB_Saquon_Barkley + 5200 RB_Spencer_Ware
#  + 5000 RB_TJ_Yeldon + 5600 RB_Tarik_Cohen + 5900 RB_Tevin_Coleman
#  + 5400 RB_Theo_Riddick + 9200 RB_Todd_Gurley + 5700 RB_Ty_Montgomery
#  + 4800 TE_Antonio_Gates + 4800 TE_Austin_Hooper
#  + 4600 TE_Austin_Seferian_Jenkins + 4900 TE_Benjamin_Watson
#  + 4000 TE_Blake_Jarwin + 5400 TE_Cameron_Brate + 5200 TE_Charles_Clay
#  + 4000 TE_Dallas_Goedert + 5300 TE_David_Njoku + 6100 TE_Delanie_Walker
#  + 5000 TE_Eric_Ebron + 6000 TE_Evan_Engram + 5300 TE_George_Kittle
#  + 6300 TE_Greg_Olsen + 5600 TE_Jack_Doyle + 6000 TE_Jared_Cook
#  + 4600 TE_Jesse_James + 6000 TE_Jimmy_Graham + 5800 TE_Jordan_Reed
#  + 5900 TE_Kyle_Rudolph + 5500 TE_Luke_Willson + 4700 TE_Mike_Gesicki
#  + 4300 TE_Nick_Vannett + 5400 TE_OJ_Howard + 5100 TE_Ricky_Seals_Jones
#  + 7900 TE_Rob_Gronkowski + 4700 TE_Ryan_Griffin + 7100 TE_Travis_Kelce
#  + 5700 TE_Trey_Burton + 5500 TE_Tyler_Eifert + 5300 TE_Tyler_Higbee
#  + 4500 TE_Vernon_Davis + 6600 TE_Zach_Ertz + 8400 WR_AJ_Green
#  + 4600 WR_Adam_Humphries + 7600 WR_Adam_Thielen + 5000 WR_Albert_Wilson
#  + 5900 WR_Allen_Hurns + 6500 WR_Allen_Robinson + 7400 WR_Amari_Cooper
#  + 5400 WR_Anthony_Miller + 9000 WR_Antonio_Brown + 4500 WR_Antonio_Callaway
#  + 4500 WR_Austin_Carr + 7600 WR_Brandin_Cooks + 5200 WR_Brandon_Marshall
#  + 4600 WR_Bruce_Ellington + 5600 WR_Calvin_Ridley + 4500 WR_Chad_Williams
#  + 4900 WR_Chester_Rogers + 4500 WR_Chris_Conley + 5500 WR_Chris_Godwin
#  + 6700 WR_Chris_Hogan + 5400 WR_Christian_Kirk + 4500 WR_Cody_Latimer
#  + 4800 WR_Cole_Beasley + 6500 WR_Cooper_Kupp + 4600 WR_Cordarrelle_Patterson
#  + 6400 WR_Corey_Davis + 4700 WR_Courtland_Sutton + 4500 WR_D.J._Chark
#  + 4800 WR_D.J._Moore + 5100 WR_Danny_Amendola + 8100 WR_Davante_Adams
#  + 8800 WR_DeAndre_Hopkins + 5900 WR_DeSean_Jackson + 5300 WR_Dede_Westbrook
#  + 7000 WR_Demaryius_Thomas + 6400 WR_Devin_Funchess + 5200 WR_Donte_Moncrief
#  + 7500 WR_Doug_Baldwin + 6300 WR_Emmanuel_Sanders + 5000 WR_Geronimo_Allison
#  + 7700 WR_Golden_Tate + 4600 WR_JJ_Nelson + 4500 WR_Jakeem_Grant
#  + 5100 WR_James_Washington + 6200 WR_Jamison_Crowder + 4500 WR_Jaron_Brown
#  + 6600 WR_Jarvis_Landry + 4900 WR_Jeremy_Kerley + 5500 WR_John_Brown
#  + 5100 WR_John_Ross + 6300 WR_Jordy_Nelson + 5700 WR_Josh_Doctson
#  + 6900 WR_Josh_Gordon + 7000 WR_JuJu_Smith_Schuster + 8300 WR_Julio_Jones
#  + 4500 WR_Keelan_Cole + 8000 WR_Keenan_Allen + 5800 WR_Kelvin_Benjamin
#  + 6100 WR_Kenny_Golladay + 6000 WR_Kenny_Stills + 4500 WR_Kevin_White
#  + 4600 WR_Laquon_Treadwell + 7300 WR_Larry_Fitzgerald
#  + 6400 WR_Marquise_Goodwin + 7500 WR_Marvin_Jones + 6600 WR_Michael_Crabtree
#  + 5500 WR_Michael_Gallup + 8500 WR_Michael_Thomas + 7700 WR_Mike_Evans
#  + 5300 WR_Mike_Wallace + 5400 WR_Mike_Williams + 5900 WR_Mohamed_Sanu
#  + 5900 WR_Nelson_Agholor + 7800 WR_Odell_Beckham_Jr + 5700 WR_Paul_Richardson
#  + 5900 WR_Phillip_Dorsett + 6200 WR_Pierre_Garcon + 5400 WR_Quincy_Enunwa
#  + 6200 WR_Randall_Cobb + 6000 WR_Rishard_Matthews + 6600 WR_Robby_Anderson
#  + 6800 WR_Robert_Woods + 4900 WR_Ryan_Grant + 6500 WR_Sammy_Watkins
#  + 4500 WR_Seth_Roberts + 7400 WR_Stefon_Diggs + 6000 WR_Sterling_Shepard
#  + 7200 WR_T.Y._Hilton + 5000 WR_Taylor_Gabriel + 4500 WR_Taywan_Taylor
#  + 6200 WR_Ted_Ginn + 5300 WR_Terrance_Williams + 5600 WR_Terrelle_Pryor
#  + 4900 WR_Torrey_Smith + 4800 WR_Travis_Benjamin + 4500 WR_Tre'Quan_Smith
#  + 4500 WR_Trent_Taylor + 4700 WR_Tyler_Boyd + 5600 WR_Tyler_Lockett
#  + 7300 WR_Tyreek_Hill + 5500 WR_Tyrell_Williams + 5100 WR_Willie_Snead
#  + 5300 WR_Zay_Jones <= 50000
#
# VARIABLES
# 0 <= DST_Arizona_Cardinals <= 1 Integer
# 0 <= DST_Atlanta_Falcons <= 1 Integer
# 0 <= DST_Baltimore_Ravens <= 1 Integer
# 0 <= DST_Buffalo_Bills <= 1 Integer
# 0 <= DST_Carolina_Panthers <= 1 Integer
# 0 <= DST_Chicago_Bears <= 1 Integer
# 0 <= DST_Cincinnati_Bengals <= 1 Integer
# 0 <= DST_Cleveland_Browns <= 1 Integer
# 0 <= DST_Dallas_Cowboys <= 1 Integer
# 0 <= DST_Denver_Broncos <= 1 Integer
# 0 <= DST_Detroit_Lions <= 1 Integer
# 0 <= DST_Green_Bay_Packers <= 1 Integer
# 0 <= DST_Houston_Texans <= 1 Integer
# 0 <= DST_Indianapolis_Colts <= 1 Integer
# 0 <= DST_Jacksonville_Jaguars <= 1 Integer
# 0 <= DST_Kansas_City_Chiefs <= 1 Integer
# 0 <= DST_Los_Angeles_Chargers <= 1 Integer
# 0 <= DST_Los_Angeles_Rams <= 1 Integer
# 0 <= DST_Miami_Dolphins <= 1 Integer
# 0 <= DST_Minnesota_Vikings <= 1 Integer
# 0 <= DST_New_England_Patriots <= 1 Integer
# 0 <= DST_New_Orleans_Saints <= 1 Integer
# 0 <= DST_New_York_Giants <= 1 Integer
# 0 <= DST_New_York_Jets <= 1 Integer
# 0 <= DST_Oakland_Raiders <= 1 Integer
# 0 <= DST_Philadelphia_Eagles <= 1 Integer
# 0 <= DST_Pittsburgh_Steelers <= 1 Integer
# 0 <= DST_San_Francisco_49ers <= 1 Integer
# 0 <= DST_Seattle_Seahawks <= 1 Integer
# 0 <= DST_Tampa_Bay_Buccaneers <= 1 Integer
# 0 <= DST_Tennessee_Titans <= 1 Integer
# 0 <= DST_Washington_Redskins <= 1 Integer
# 0 <= FLEX_AJ_Green <= 1 Integer
# 0 <= FLEX_Adam_Humphries <= 1 Integer
# 0 <= FLEX_Adam_Thielen <= 1 Integer
# 0 <= FLEX_Adrian_Peterson <= 1 Integer
# 0 <= FLEX_Albert_Wilson <= 1 Integer
# 0 <= FLEX_Alex_Collins <= 1 Integer
# 0 <= FLEX_Alfred_Blue <= 1 Integer
# 0 <= FLEX_Alfred_Morris <= 1 Integer
# 0 <= FLEX_Allen_Hurns <= 1 Integer
# 0 <= FLEX_Allen_Robinson <= 1 Integer
# 0 <= FLEX_Alvin_Kamara <= 1 Integer
# 0 <= FLEX_Amari_Cooper <= 1 Integer
# 0 <= FLEX_Anthony_Miller <= 1 Integer
# 0 <= FLEX_Antonio_Brown <= 1 Integer
# 0 <= FLEX_Antonio_Callaway <= 1 Integer
# 0 <= FLEX_Antonio_Gates <= 1 Integer
# 0 <= FLEX_Austin_Carr <= 1 Integer
# 0 <= FLEX_Austin_Ekeler <= 1 Integer
# 0 <= FLEX_Austin_Hooper <= 1 Integer
# 0 <= FLEX_Austin_Seferian_Jenkins <= 1 Integer
# 0 <= FLEX_Benjamin_Watson <= 1 Integer
# 0 <= FLEX_Bilal_Powell <= 1 Integer
# 0 <= FLEX_Blake_Jarwin <= 1 Integer
# 0 <= FLEX_Brandin_Cooks <= 1 Integer
# 0 <= FLEX_Brandon_Marshall <= 1 Integer
# 0 <= FLEX_Bruce_Ellington <= 1 Integer
# 0 <= FLEX_CJ_Anderson <= 1 Integer
# 0 <= FLEX_Calvin_Ridley <= 1 Integer
# 0 <= FLEX_Cameron_Brate <= 1 Integer
# 0 <= FLEX_Carlos_Hyde <= 1 Integer
# 0 <= FLEX_Chad_Williams <= 1 Integer
# 0 <= FLEX_Charles_Clay <= 1 Integer
# 0 <= FLEX_Chase_Edmonds <= 1 Integer
# 0 <= FLEX_Chester_Rogers <= 1 Integer
# 0 <= FLEX_Chris_Carson <= 1 Integer
# 0 <= FLEX_Chris_Conley <= 1 Integer
# 0 <= FLEX_Chris_Godwin <= 1 Integer
# 0 <= FLEX_Chris_Hogan <= 1 Integer
# 0 <= FLEX_Chris_Ivory <= 1 Integer
# 0 <= FLEX_Chris_Thompson <= 1 Integer
# 0 <= FLEX_Christian_Kirk <= 1 Integer
# 0 <= FLEX_Christian_McCaffrey <= 1 Integer
# 0 <= FLEX_Christine_Michael <= 1 Integer
# 0 <= FLEX_Cody_Latimer <= 1 Integer
# 0 <= FLEX_Cole_Beasley <= 1 Integer
# 0 <= FLEX_Cooper_Kupp <= 1 Integer
# 0 <= FLEX_Cordarrelle_Patterson <= 1 Integer
# 0 <= FLEX_Corey_Clement <= 1 Integer
# 0 <= FLEX_Corey_Davis <= 1 Integer
# 0 <= FLEX_Corey_Grant <= 1 Integer
# 0 <= FLEX_Courtland_Sutton <= 1 Integer
# 0 <= FLEX_D.J._Chark <= 1 Integer
# 0 <= FLEX_D.J._Moore <= 1 Integer
# 0 <= FLEX_Dallas_Goedert <= 1 Integer
# 0 <= FLEX_Dalvin_Cook <= 1 Integer
# 0 <= FLEX_Danny_Amendola <= 1 Integer
# 0 <= FLEX_Darren_Sproles <= 1 Integer
# 0 <= FLEX_Davante_Adams <= 1 Integer
# 0 <= FLEX_David_Johnson <= 1 Integer
# 0 <= FLEX_David_Njoku <= 1 Integer
# 0 <= FLEX_DeAndre_Hopkins <= 1 Integer
# 0 <= FLEX_DeSean_Jackson <= 1 Integer
# 0 <= FLEX_Dede_Westbrook <= 1 Integer
# 0 <= FLEX_Delanie_Walker <= 1 Integer
# 0 <= FLEX_Demaryius_Thomas <= 1 Integer
# 0 <= FLEX_Derrick_Henry <= 1 Integer
# 0 <= FLEX_Devin_Funchess <= 1 Integer
# 0 <= FLEX_Devonta_Freeman <= 1 Integer
# 0 <= FLEX_Devontae_Booker <= 1 Integer
# 0 <= FLEX_Dion_Lewis <= 1 Integer
# 0 <= FLEX_Donte_Moncrief <= 1 Integer
# 0 <= FLEX_Doug_Baldwin <= 1 Integer
# 0 <= FLEX_Doug_Martin <= 1 Integer
# 0 <= FLEX_Duke_Johnson <= 1 Integer
# 0 <= FLEX_Emmanuel_Sanders <= 1 Integer
# 0 <= FLEX_Eric_Ebron <= 1 Integer
# 0 <= FLEX_Evan_Engram <= 1 Integer
# 0 <= FLEX_Ezekiel_Elliott <= 1 Integer
# 0 <= FLEX_Frank_Gore <= 1 Integer
# 0 <= FLEX_George_Kittle <= 1 Integer
# 0 <= FLEX_Geronimo_Allison <= 1 Integer
# 0 <= FLEX_Giovani_Bernard <= 1 Integer
# 0 <= FLEX_Golden_Tate <= 1 Integer
# 0 <= FLEX_Greg_Olsen <= 1 Integer
# 0 <= FLEX_Isaiah_Crowell <= 1 Integer
# 0 <= FLEX_JJ_Nelson <= 1 Integer
# 0 <= FLEX_Jack_Doyle <= 1 Integer
# 0 <= FLEX_Jakeem_Grant <= 1 Integer
# 0 <= FLEX_Jalen_Richard <= 1 Integer
# 0 <= FLEX_Jamaal_Williams <= 1 Integer
# 0 <= FLEX_James_Conner <= 1 Integer
# 0 <= FLEX_James_Washington <= 1 Integer
# 0 <= FLEX_James_White <= 1 Integer
# 0 <= FLEX_Jamison_Crowder <= 1 Integer
# 0 <= FLEX_Jared_Cook <= 1 Integer
# 0 <= FLEX_Jaron_Brown <= 1 Integer
# 0 <= FLEX_Jarvis_Landry <= 1 Integer
# 0 <= FLEX_Javorius_Allen <= 1 Integer
# 0 <= FLEX_Jay_Ajayi <= 1 Integer
# 0 <= FLEX_Jaylen_Samuels <= 1 Integer
# 0 <= FLEX_Jeremy_Hill <= 1 Integer
# 0 <= FLEX_Jeremy_Kerley <= 1 Integer
# 0 <= FLEX_Jesse_James <= 1 Integer
# 0 <= FLEX_Jimmy_Graham <= 1 Integer
# 0 <= FLEX_Joe_Mixon <= 1 Integer
# 0 <= FLEX_John_Brown <= 1 Integer
# 0 <= FLEX_John_Ross <= 1 Integer
# 0 <= FLEX_Jordan_Howard <= 1 Integer
# 0 <= FLEX_Jordan_Reed <= 1 Integer
# 0 <= FLEX_Jordan_Wilkins <= 1 Integer
# 0 <= FLEX_Jordy_Nelson <= 1 Integer
# 0 <= FLEX_Josh_Doctson <= 1 Integer
# 0 <= FLEX_Josh_Gordon <= 1 Integer
# 0 <= FLEX_JuJu_Smith_Schuster <= 1 Integer
# 0 <= FLEX_Julio_Jones <= 1 Integer
# 0 <= FLEX_Kareem_Hunt <= 1 Integer
# 0 <= FLEX_Keelan_Cole <= 1 Integer
# 0 <= FLEX_Keenan_Allen <= 1 Integer
# 0 <= FLEX_Kelvin_Benjamin <= 1 Integer
# 0 <= FLEX_Kenneth_Dixon <= 1 Integer
# 0 <= FLEX_Kenny_Golladay <= 1 Integer
# 0 <= FLEX_Kenny_Stills <= 1 Integer
# 0 <= FLEX_Kenyan_Drake <= 1 Integer
# 0 <= FLEX_Kerryon_Johnson <= 1 Integer
# 0 <= FLEX_Kevin_White <= 1 Integer
# 0 <= FLEX_Kyle_Juszczyk <= 1 Integer
# 0 <= FLEX_Kyle_Rudolph <= 1 Integer
# 0 <= FLEX_Lamar_Miller <= 1 Integer
# 0 <= FLEX_Laquon_Treadwell <= 1 Integer
# 0 <= FLEX_Larry_Fitzgerald <= 1 Integer
# 0 <= FLEX_Latavius_Murray <= 1 Integer
# 0 <= FLEX_LeGarrette_Blount <= 1 Integer
# 0 <= FLEX_LeSean_McCoy <= 1 Integer
# 0 <= FLEX_Leonard_Fournette <= 1 Integer
# 0 <= FLEX_Luke_Willson <= 1 Integer
# 0 <= FLEX_Marquise_Goodwin <= 1 Integer
# 0 <= FLEX_Marshawn_Lynch <= 1 Integer
# 0 <= FLEX_Marvin_Jones <= 1 Integer
# 0 <= FLEX_Matt_Breida <= 1 Integer
# 0 <= FLEX_Melvin_Gordon <= 1 Integer
# 0 <= FLEX_Michael_Crabtree <= 1 Integer
# 0 <= FLEX_Michael_Gallup <= 1 Integer
# 0 <= FLEX_Michael_Thomas <= 1 Integer
# 0 <= FLEX_Mike_Evans <= 1 Integer
# 0 <= FLEX_Mike_Gesicki <= 1 Integer
# 0 <= FLEX_Mike_Gillislee <= 1 Integer
# 0 <= FLEX_Mike_Wallace <= 1 Integer
# 0 <= FLEX_Mike_Williams <= 1 Integer
# 0 <= FLEX_Mohamed_Sanu <= 1 Integer
# 0 <= FLEX_Nelson_Agholor <= 1 Integer
# 0 <= FLEX_Nick_Vannett <= 1 Integer
# 0 <= FLEX_Nyheim_Hines <= 1 Integer
# 0 <= FLEX_OJ_Howard <= 1 Integer
# 0 <= FLEX_Odell_Beckham_Jr <= 1 Integer
# 0 <= FLEX_Paul_Richardson <= 1 Integer
# 0 <= FLEX_Peyton_Barber <= 1 Integer
# 0 <= FLEX_Phillip_Dorsett <= 1 Integer
# 0 <= FLEX_Pierre_Garcon <= 1 Integer
# 0 <= FLEX_Quincy_Enunwa <= 1 Integer
# 0 <= FLEX_Randall_Cobb <= 1 Integer
# 0 <= FLEX_Rashaad_Penny <= 1 Integer
# 0 <= FLEX_Rex_Burkhead <= 1 Integer
# 0 <= FLEX_Ricky_Seals_Jones <= 1 Integer
# 0 <= FLEX_Rishard_Matthews <= 1 Integer
# 0 <= FLEX_Rob_Gronkowski <= 1 Integer
# 0 <= FLEX_Robby_Anderson <= 1 Integer
# 0 <= FLEX_Robert_Woods <= 1 Integer
# 0 <= FLEX_Royce_Freeman <= 1 Integer
# 0 <= FLEX_Ryan_Grant <= 1 Integer
# 0 <= FLEX_Ryan_Griffin <= 1 Integer
# 0 <= FLEX_Sammy_Watkins <= 1 Integer
# 0 <= FLEX_Saquon_Barkley <= 1 Integer
# 0 <= FLEX_Seth_Roberts <= 1 Integer
# 0 <= FLEX_Spencer_Ware <= 1 Integer
# 0 <= FLEX_Stefon_Diggs <= 1 Integer
# 0 <= FLEX_Sterling_Shepard <= 1 Integer
# 0 <= FLEX_T.Y._Hilton <= 1 Integer
# 0 <= FLEX_TJ_Yeldon <= 1 Integer
# 0 <= FLEX_Tarik_Cohen <= 1 Integer
# 0 <= FLEX_Taylor_Gabriel <= 1 Integer
# 0 <= FLEX_Taywan_Taylor <= 1 Integer
# 0 <= FLEX_Ted_Ginn <= 1 Integer
# 0 <= FLEX_Terrance_Williams <= 1 Integer
# 0 <= FLEX_Terrelle_Pryor <= 1 Integer
# 0 <= FLEX_Tevin_Coleman <= 1 Integer
# 0 <= FLEX_Theo_Riddick <= 1 Integer
# 0 <= FLEX_Todd_Gurley <= 1 Integer
# 0 <= FLEX_Torrey_Smith <= 1 Integer
# 0 <= FLEX_Travis_Benjamin <= 1 Integer
# 0 <= FLEX_Travis_Kelce <= 1 Integer
# 0 <= FLEX_Tre'Quan_Smith <= 1 Integer
# 0 <= FLEX_Trent_Taylor <= 1 Integer
# 0 <= FLEX_Trey_Burton <= 1 Integer
# 0 <= FLEX_Ty_Montgomery <= 1 Integer
# 0 <= FLEX_Tyler_Boyd <= 1 Integer
# 0 <= FLEX_Tyler_Eifert <= 1 Integer
# 0 <= FLEX_Tyler_Higbee <= 1 Integer
# 0 <= FLEX_Tyler_Lockett <= 1 Integer
# 0 <= FLEX_Tyreek_Hill <= 1 Integer
# 0 <= FLEX_Tyrell_Williams <= 1 Integer
# 0 <= FLEX_Vernon_Davis <= 1 Integer
# 0 <= FLEX_Willie_Snead <= 1 Integer
# 0 <= FLEX_Zach_Ertz <= 1 Integer
# 0 <= FLEX_Zay_Jones <= 1 Integer
# 0 <= K_Adam_Vinatieri <= 1 Integer
# 0 <= K_Aldrick_Rosas <= 1 Integer
# 0 <= K_Brandon_McManus <= 1 Integer
# 0 <= K_Brett_Maher <= 1 Integer
# 0 <= K_Caleb_Sturgis <= 1 Integer
# 0 <= K_Chandler_Catanzaro <= 1 Integer
# 0 <= K_Chris_Boswell <= 1 Integer
# 0 <= K_Cody_Parkey <= 1 Integer
# 0 <= K_Daniel_Carlson <= 1 Integer
# 0 <= K_Dustin_Hopkins <= 1 Integer
# 0 <= K_Graham_Gano <= 1 Integer
# 0 <= K_Greg_Zuerlein <= 1 Integer
# 0 <= K_Harrison_Butker <= 1 Integer
# 0 <= K_Jake_Elliott <= 1 Integer
# 0 <= K_Jason_Myers <= 1 Integer
# 0 <= K_Jason_Sanders <= 1 Integer
# 0 <= K_Josh_Lambo <= 1 Integer
# 0 <= K_Justin_Tucker <= 1 Integer
# 0 <= K_Ka'imi_Fairbairn <= 1 Integer
# 0 <= K_Mason_Crosby <= 1 Integer
# 0 <= K_Matt_Bryant <= 1 Integer
# 0 <= K_Matt_Prater <= 1 Integer
# 0 <= K_Mike_Nugent <= 1 Integer
# 0 <= K_Phil_Dawson <= 1 Integer
# 0 <= K_Randy_Bullock <= 1 Integer
# 0 <= K_Robbie_Gould <= 1 Integer
# 0 <= K_Ryan_Succop <= 1 Integer
# 0 <= K_Sebastian_Janikowski <= 1 Integer
# 0 <= K_Stephen_Gostkowski <= 1 Integer
# 0 <= K_Steven_Hauschka <= 1 Integer
# 0 <= K_Wil_Lutz <= 1 Integer
# 0 <= K_Zane_Gonzalez <= 1 Integer
# 0 <= QB_Aaron_Rodgers <= 1 Integer
# 0 <= QB_Alex_Smith <= 1 Integer
# 0 <= QB_Andrew_Luck <= 1 Integer
# 0 <= QB_Andy_Dalton <= 1 Integer
# 0 <= QB_Ben_Roethlisberger <= 1 Integer
# 0 <= QB_Blake_Bortles <= 1 Integer
# 0 <= QB_Cam_Newton <= 1 Integer
# 0 <= QB_Case_Keenum <= 1 Integer
# 0 <= QB_Dak_Prescott <= 1 Integer
# 0 <= QB_Derek_Carr <= 1 Integer
# 0 <= QB_Deshaun_Watson <= 1 Integer
# 0 <= QB_Drew_Brees <= 1 Integer
# 0 <= QB_Eli_Manning <= 1 Integer
# 0 <= QB_Jared_Goff <= 1 Integer
# 0 <= QB_Jimmy_Garoppolo <= 1 Integer
# 0 <= QB_Joe_Flacco <= 1 Integer
# 0 <= QB_Kirk_Cousins <= 1 Integer
# 0 <= QB_Marcus_Mariota <= 1 Integer
# 0 <= QB_Matt_Ryan <= 1 Integer
# 0 <= QB_Matthew_Stafford <= 1 Integer
# 0 <= QB_Mitch_Trubisky <= 1 Integer
# 0 <= QB_Nathan_Peterman <= 1 Integer
# 0 <= QB_Nick_Foles <= 1 Integer
# 0 <= QB_Patrick_Mahomes <= 1 Integer
# 0 <= QB_Philip_Rivers <= 1 Integer
# 0 <= QB_Russell_Wilson <= 1 Integer
# 0 <= QB_Ryan_Fitzpatrick <= 1 Integer
# 0 <= QB_Ryan_Tannehill <= 1 Integer
# 0 <= QB_Sam_Bradford <= 1 Integer
# 0 <= QB_Sam_Darnold <= 1 Integer
# 0 <= QB_Tom_Brady <= 1 Integer
# 0 <= QB_Tyrod_Taylor <= 1 Integer
# 0 <= RB_Adrian_Peterson <= 1 Integer
# 0 <= RB_Alex_Collins <= 1 Integer
# 0 <= RB_Alfred_Blue <= 1 Integer
# 0 <= RB_Alfred_Morris <= 1 Integer
# 0 <= RB_Alvin_Kamara <= 1 Integer
# 0 <= RB_Austin_Ekeler <= 1 Integer
# 0 <= RB_Bilal_Powell <= 1 Integer
# 0 <= RB_CJ_Anderson <= 1 Integer
# 0 <= RB_Carlos_Hyde <= 1 Integer
# 0 <= RB_Chase_Edmonds <= 1 Integer
# 0 <= RB_Chris_Carson <= 1 Integer
# 0 <= RB_Chris_Ivory <= 1 Integer
# 0 <= RB_Chris_Thompson <= 1 Integer
# 0 <= RB_Christian_McCaffrey <= 1 Integer
# 0 <= RB_Christine_Michael <= 1 Integer
# 0 <= RB_Corey_Clement <= 1 Integer
# 0 <= RB_Corey_Grant <= 1 Integer
# 0 <= RB_Dalvin_Cook <= 1 Integer
# 0 <= RB_Darren_Sproles <= 1 Integer
# 0 <= RB_David_Johnson <= 1 Integer
# 0 <= RB_Derrick_Henry <= 1 Integer
# 0 <= RB_Devonta_Freeman <= 1 Integer
# 0 <= RB_Devontae_Booker <= 1 Integer
# 0 <= RB_Dion_Lewis <= 1 Integer
# 0 <= RB_Doug_Martin <= 1 Integer
# 0 <= RB_Duke_Johnson <= 1 Integer
# 0 <= RB_Ezekiel_Elliott <= 1 Integer
# 0 <= RB_Frank_Gore <= 1 Integer
# 0 <= RB_Giovani_Bernard <= 1 Integer
# 0 <= RB_Isaiah_Crowell <= 1 Integer
# 0 <= RB_Jalen_Richard <= 1 Integer
# 0 <= RB_Jamaal_Williams <= 1 Integer
# 0 <= RB_James_Conner <= 1 Integer
# 0 <= RB_James_White <= 1 Integer
# 0 <= RB_Javorius_Allen <= 1 Integer
# 0 <= RB_Jay_Ajayi <= 1 Integer
# 0 <= RB_Jaylen_Samuels <= 1 Integer
# 0 <= RB_Jeremy_Hill <= 1 Integer
# 0 <= RB_Joe_Mixon <= 1 Integer
# 0 <= RB_Jordan_Howard <= 1 Integer
# 0 <= RB_Jordan_Wilkins <= 1 Integer
# 0 <= RB_Kareem_Hunt <= 1 Integer
# 0 <= RB_Kenneth_Dixon <= 1 Integer
# 0 <= RB_Kenyan_Drake <= 1 Integer
# 0 <= RB_Kerryon_Johnson <= 1 Integer
# 0 <= RB_Kyle_Juszczyk <= 1 Integer
# 0 <= RB_Lamar_Miller <= 1 Integer
# 0 <= RB_Latavius_Murray <= 1 Integer
# 0 <= RB_LeGarrette_Blount <= 1 Integer
# 0 <= RB_LeSean_McCoy <= 1 Integer
# 0 <= RB_Leonard_Fournette <= 1 Integer
# 0 <= RB_Marshawn_Lynch <= 1 Integer
# 0 <= RB_Matt_Breida <= 1 Integer
# 0 <= RB_Melvin_Gordon <= 1 Integer
# 0 <= RB_Mike_Gillislee <= 1 Integer
# 0 <= RB_Nyheim_Hines <= 1 Integer
# 0 <= RB_Peyton_Barber <= 1 Integer
# 0 <= RB_Rashaad_Penny <= 1 Integer
# 0 <= RB_Rex_Burkhead <= 1 Integer
# 0 <= RB_Royce_Freeman <= 1 Integer
# 0 <= RB_Saquon_Barkley <= 1 Integer
# 0 <= RB_Spencer_Ware <= 1 Integer
# 0 <= RB_TJ_Yeldon <= 1 Integer
# 0 <= RB_Tarik_Cohen <= 1 Integer
# 0 <= RB_Tevin_Coleman <= 1 Integer
# 0 <= RB_Theo_Riddick <= 1 Integer
# 0 <= RB_Todd_Gurley <= 1 Integer
# 0 <= RB_Ty_Montgomery <= 1 Integer
# 0 <= TE_Antonio_Gates <= 1 Integer
# 0 <= TE_Austin_Hooper <= 1 Integer
# 0 <= TE_Austin_Seferian_Jenkins <= 1 Integer
# 0 <= TE_Benjamin_Watson <= 1 Integer
# 0 <= TE_Blake_Jarwin <= 1 Integer
# 0 <= TE_Cameron_Brate <= 1 Integer
# 0 <= TE_Charles_Clay <= 1 Integer
# 0 <= TE_Dallas_Goedert <= 1 Integer
# 0 <= TE_David_Njoku <= 1 Integer
# 0 <= TE_Delanie_Walker <= 1 Integer
# 0 <= TE_Eric_Ebron <= 1 Integer
# 0 <= TE_Evan_Engram <= 1 Integer
# 0 <= TE_George_Kittle <= 1 Integer
# 0 <= TE_Greg_Olsen <= 1 Integer
# 0 <= TE_Jack_Doyle <= 1 Integer
# 0 <= TE_Jared_Cook <= 1 Integer
# 0 <= TE_Jesse_James <= 1 Integer
# 0 <= TE_Jimmy_Graham <= 1 Integer
# 0 <= TE_Jordan_Reed <= 1 Integer
# 0 <= TE_Kyle_Rudolph <= 1 Integer
# 0 <= TE_Luke_Willson <= 1 Integer
# 0 <= TE_Mike_Gesicki <= 1 Integer
# 0 <= TE_Nick_Vannett <= 1 Integer
# 0 <= TE_OJ_Howard <= 1 Integer
# 0 <= TE_Ricky_Seals_Jones <= 1 Integer
# 0 <= TE_Rob_Gronkowski <= 1 Integer
# 0 <= TE_Ryan_Griffin <= 1 Integer
# 0 <= TE_Travis_Kelce <= 1 Integer
# 0 <= TE_Trey_Burton <= 1 Integer
# 0 <= TE_Tyler_Eifert <= 1 Integer
# 0 <= TE_Tyler_Higbee <= 1 Integer
# 0 <= TE_Vernon_Davis <= 1 Integer
# 0 <= TE_Zach_Ertz <= 1 Integer
# 0 <= WR_AJ_Green <= 1 Integer
# 0 <= WR_Adam_Humphries <= 1 Integer
# 0 <= WR_Adam_Thielen <= 1 Integer
# 0 <= WR_Albert_Wilson <= 1 Integer
# 0 <= WR_Allen_Hurns <= 1 Integer
# 0 <= WR_Allen_Robinson <= 1 Integer
# 0 <= WR_Amari_Cooper <= 1 Integer
# 0 <= WR_Anthony_Miller <= 1 Integer
# 0 <= WR_Antonio_Brown <= 1 Integer
# 0 <= WR_Antonio_Callaway <= 1 Integer
# 0 <= WR_Austin_Carr <= 1 Integer
# 0 <= WR_Brandin_Cooks <= 1 Integer
# 0 <= WR_Brandon_Marshall <= 1 Integer
# 0 <= WR_Bruce_Ellington <= 1 Integer
# 0 <= WR_Calvin_Ridley <= 1 Integer
# 0 <= WR_Chad_Williams <= 1 Integer
# 0 <= WR_Chester_Rogers <= 1 Integer
# 0 <= WR_Chris_Conley <= 1 Integer
# 0 <= WR_Chris_Godwin <= 1 Integer
# 0 <= WR_Chris_Hogan <= 1 Integer
# 0 <= WR_Christian_Kirk <= 1 Integer
# 0 <= WR_Cody_Latimer <= 1 Integer
# 0 <= WR_Cole_Beasley <= 1 Integer
# 0 <= WR_Cooper_Kupp <= 1 Integer
# 0 <= WR_Cordarrelle_Patterson <= 1 Integer
# 0 <= WR_Corey_Davis <= 1 Integer
# 0 <= WR_Courtland_Sutton <= 1 Integer
# 0 <= WR_D.J._Chark <= 1 Integer
# 0 <= WR_D.J._Moore <= 1 Integer
# 0 <= WR_Danny_Amendola <= 1 Integer
# 0 <= WR_Davante_Adams <= 1 Integer
# 0 <= WR_DeAndre_Hopkins <= 1 Integer
# 0 <= WR_DeSean_Jackson <= 1 Integer
# 0 <= WR_Dede_Westbrook <= 1 Integer
# 0 <= WR_Demaryius_Thomas <= 1 Integer
# 0 <= WR_Devin_Funchess <= 1 Integer
# 0 <= WR_Donte_Moncrief <= 1 Integer
# 0 <= WR_Doug_Baldwin <= 1 Integer
# 0 <= WR_Emmanuel_Sanders <= 1 Integer
# 0 <= WR_Geronimo_Allison <= 1 Integer
# 0 <= WR_Golden_Tate <= 1 Integer
# 0 <= WR_JJ_Nelson <= 1 Integer
# 0 <= WR_Jakeem_Grant <= 1 Integer
# 0 <= WR_James_Washington <= 1 Integer
# 0 <= WR_Jamison_Crowder <= 1 Integer
# 0 <= WR_Jaron_Brown <= 1 Integer
# 0 <= WR_Jarvis_Landry <= 1 Integer
# 0 <= WR_Jeremy_Kerley <= 1 Integer
# 0 <= WR_John_Brown <= 1 Integer
# 0 <= WR_John_Ross <= 1 Integer
# 0 <= WR_Jordy_Nelson <= 1 Integer
# 0 <= WR_Josh_Doctson <= 1 Integer
# 0 <= WR_Josh_Gordon <= 1 Integer
# 0 <= WR_JuJu_Smith_Schuster <= 1 Integer
# 0 <= WR_Julio_Jones <= 1 Integer
# 0 <= WR_Keelan_Cole <= 1 Integer
# 0 <= WR_Keenan_Allen <= 1 Integer
# 0 <= WR_Kelvin_Benjamin <= 1 Integer
# 0 <= WR_Kenny_Golladay <= 1 Integer
# 0 <= WR_Kenny_Stills <= 1 Integer
# 0 <= WR_Kevin_White <= 1 Integer
# 0 <= WR_Laquon_Treadwell <= 1 Integer
# 0 <= WR_Larry_Fitzgerald <= 1 Integer
# 0 <= WR_Marquise_Goodwin <= 1 Integer
# 0 <= WR_Marvin_Jones <= 1 Integer
# 0 <= WR_Michael_Crabtree <= 1 Integer
# 0 <= WR_Michael_Gallup <= 1 Integer
# 0 <= WR_Michael_Thomas <= 1 Integer
# 0 <= WR_Mike_Evans <= 1 Integer
# 0 <= WR_Mike_Wallace <= 1 Integer
# 0 <= WR_Mike_Williams <= 1 Integer
# 0 <= WR_Mohamed_Sanu <= 1 Integer
# 0 <= WR_Nelson_Agholor <= 1 Integer
# 0 <= WR_Odell_Beckham_Jr <= 1 Integer
# 0 <= WR_Paul_Richardson <= 1 Integer
# 0 <= WR_Phillip_Dorsett <= 1 Integer
# 0 <= WR_Pierre_Garcon <= 1 Integer
# 0 <= WR_Quincy_Enunwa <= 1 Integer
# 0 <= WR_Randall_Cobb <= 1 Integer
# 0 <= WR_Rishard_Matthews <= 1 Integer
# 0 <= WR_Robby_Anderson <= 1 Integer
# 0 <= WR_Robert_Woods <= 1 Integer
# 0 <= WR_Ryan_Grant <= 1 Integer
# 0 <= WR_Sammy_Watkins <= 1 Integer
# 0 <= WR_Seth_Roberts <= 1 Integer
# 0 <= WR_Stefon_Diggs <= 1 Integer
# 0 <= WR_Sterling_Shepard <= 1 Integer
# 0 <= WR_T.Y._Hilton <= 1 Integer
# 0 <= WR_Taylor_Gabriel <= 1 Integer
# 0 <= WR_Taywan_Taylor <= 1 Integer
# 0 <= WR_Ted_Ginn <= 1 Integer
# 0 <= WR_Terrance_Williams <= 1 Integer
# 0 <= WR_Terrelle_Pryor <= 1 Integer
# 0 <= WR_Torrey_Smith <= 1 Integer
# 0 <= WR_Travis_Benjamin <= 1 Integer
# 0 <= WR_Tre'Quan_Smith <= 1 Integer
# 0 <= WR_Trent_Taylor <= 1 Integer
# 0 <= WR_Tyler_Boyd <= 1 Integer
# 0 <= WR_Tyler_Lockett <= 1 Integer
# 0 <= WR_Tyreek_Hill <= 1 Integer
# 0 <= WR_Tyrell_Williams <= 1 Integer
# 0 <= WR_Willie_Snead <= 1 Integer
# 0 <= WR_Zay_Jones <= 1 Integer

# %% [markdown]
# ### Solve Optimization Problem

# %%
prob.solve()
# Out:
# 1

# %%
def summary(prob):
    div = '---------------------------------------\n'
    print("Variables:\n")
    score = str(prob.objective)
    constraints = [str(const) for const in prob.constraints.values()]
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraints = [const.replace(v.name, str(v.varValue)) for const in constraints]
        if v.varValue != 0:
            print(v.name, "=", v.varValue)
    print(div)
    print("Constraints:")
    for constraint in constraints:
        constraint_pretty = " + ".join(re.findall("[0-9\.]*\*1.0", constraint))
        if constraint_pretty != "":
            print("{} = {}".format(constraint_pretty, eval(constraint_pretty)))
    print(div)
    print("Score:")
    score_pretty = " + ".join(re.findall("[0-9\.]+\*1.0", score))
    print("{} = {}".format(score_pretty, eval(score)))

# %%
summary(prob)
# Out:
# Variables:
#
# DST_Miami_Dolphins = 1.0
# FLEX_James_Conner = 1.0
# K_Randy_Bullock = 1.0
# QB_Ryan_Fitzpatrick = 1.0
# RB_Alvin_Kamara = 1.0
# RB_David_Johnson = 1.0
# TE_Dallas_Goedert = 1.0
# WR_Keelan_Cole = 1.0
# WR_Nelson_Agholor = 1.0
# ---------------------------------------
#
# Constraints:
# 3200*1.0 + 5000*1.0 + 3900*1.0 + 6200*1.0 + 8700*1.0 + 8600*1.0 + 4000*1.0 + 4500*1.0 + 5900*1.0 = 50000.0
# ---------------------------------------
#
# Score:
# 6.2*1.0 + 12.76*1.0 + 7.89*1.0 + 15.58*1.0 + 19.72*1.0 + 19.52*1.0 + 4.57*1.0 + 8.85*1.0 + 10.6*1.0 = 105.69

# %% [markdown]
# ### Week 1
#
# Variables:
#
# DST_Miami_Dolphins = 1.0 <br>
# FLEX_James_Conner = 1.0 <br>
# K_Randy_Bullock = 1.0 <br>
# QB_Ryan_Fitzpatrick = 1.0 <br>
# RB_Alvin_Kamara = 1.0 <br>
# RB_David_Johnson = 1.0 <br>
# TE_Dallas_Goedert = 1.0 <br>
# WR_Keelan_Cole = 1.0 <br>
# WR_Nelson_Agholor = 1.0
#
# **---------------------------------------**
#
# Constraints:
# 3200* 1.0 + 5000* 1.0 + 3900* 1.0 + 6200* 1.0 + 8700* 1.0 + 8600* 1.0 + 4000* 1.0 + 4500* 1.0 + 5900* 1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 6.2* 1.0 + 12.76* 1.0 + 7.89* 1.0 + 15.58* 1.0 + 19.72* 1.0 + 19.52* 1.0 + 4.57* 1.0 + 8.85* 1.0 + 10.6* 1.0 = 105.69

# %% [markdown]
# ### Week 10
#
# Variables:
#
# DST_New_Orleans_Saints = 1.0 <br>
# FLEX_Isaiah_Crowell = 1.0 <br>
# K_Dustin_Hopkins = 1.0 <br>
# QB_Ben_Roethlisberger = 1.0 <br>
# RB_Dion_Lewis = 1.0 <br>
# RB_James_Conner = 1.0 <br>
# TE_Jordan_Reed = 1.0 <br>
# WR_Josh_Doctson = 1.0 <br>
# WR_Marquez_Valdes_Scantling = 1.0 <br>
#
# **---------------------------------------**
#
# Constraints:
# 3200* 1.0 + 5400* 1.0 + 4100* 1.0 + 7800* 1.0 + 5800* 1.0 + 8200* 1.0 + 5200* 1.0 + 4900* 1.0 + 5400* 1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 6.6* 1.0 + 10.11* 1.0 + 7.99* 1.0 + 20.49* 1.0 + 11.82* 1.0 + 18.71* 1.0 + 8.52* 1.0 + 8.31* 1.0 + 10.56* 1.0 = 103.11

# %% [markdown]
# ### Week 11
#
# Variables:
#
# DST_Seattle_Seahawks = 1.0 <br>
# FLEX_John_Brown = 1.0 <br>
# K_Wil_Lutz = 1.0 <br>
# QB_Carson_Wentz = 1.0 <br>
# RB_David_Johnson = 1.0 <br>
# RB_Dion_Lewis = 1.0 <br>
# TE_James_O'Shaughnessy = 1.0 <br>
# WR_Devin_Funchess = 1.0 <br>
# WR_Marquez_Valdes_Scantling = 1.0 <br>
#
# **---------------------------------------**
#
# Constraints:
# 3100* 1.0 + 5400* 1.0 + 5000* 1.0 + 7700* 1.0 + 7900* 1.0 + 5900* 1.0 + 4000* 1.0 + 5700* 1.0 + 5300* 1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 6.7* 1.0 + 10.19* 1.0 + 11.28* 1.0 + 21.25* 1.0 + 18.56* 1.0 + 12.16* 1.0 + 5.43* 1.0 + 10.95* 1.0 + 10.88* 1.0 = 107.39999999999999

# %% [markdown]
# ### Week 12
#
# Variables:
#
# DST_Cleveland_Browns = 1.0 <br>
# FLEX_James_Conner = 1.0 <br>
# K_Wil_Lutz = 1.0 <br>
# QB_Nick_Mullens = 1.0 <br>
# RB_Gus_Edwards = 1.0 <br>
# RB_Matt_Breida = 1.0 <br>
# TE_Cameron_Brate = 1.0 <br>
# WR_D.J._Moore = 1.0 <br>
# WR_Jarvis_Landry = 1.0 <br>
#
# **---------------------------------------**
#
# Constraints:
# 3100* 1.0 + 7900* 1.0 + 5000* 1.0 + 6000* 1.0 + 5300* 1.0 + 6400* 1.0 + 4400* 1.0 + 5800* 1.0 + 6100* 1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 6.6* 1.0 + 18.39* 1.0 + 11.51* 1.0 + 16.69* 1.0 + 10.23* 1.0 + 13.51* 1.0 + 8.03* 1.0 + 10.5* 1.0 + 11.15* 1.0 = 106.61000000000001

# %% [markdown]
# ### Week 13
#
# Variables:
#
# DST_Carolina_Panthers = 1.0 <br>
# FLEX_TJ_Yeldon = 1.0 <br>
# K_Michael_Badgley = 1.0 <br>
# QB_Jameis_Winston = 1.0 <br>
# RB_Austin_Ekeler = 1.0 <br>
# RB_Spencer_Ware = 1.0 <br>
# TE_Eric_Ebron = 1.0 <br>
# WR_Corey_Davis = 1.0 <br>
# WR_Tyreek_Hill = 1.0 <br>
#
# **---------------------------------------**
#
# Constraints:
# 3800* 1.0 + 4800* 1.0 + 3400*  1.0 + 7500* 1.0 + 5400* 1.0 + 5200* 1.0 + 5600* 1.0 + 5900* 1.0 + 8400* 1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 8.5* 1.0 + 10.1* 1.0 + 8.34* 1.0 + 21.31* 1.0 + 13.54* 1.0 + 14.33* 1.0 + 11.13* 1.0 + 11.64* 1.0 + 17.18* 1.0 = 116.07

# %% [markdown]
# ### Week 14
#
# Variables:
#
# DST_Dallas_Cowboys = 1.0 <br>
# FLEX_Justin_Jackson = 1.0 <br>
# K_Steven_Hauschka = 1.0 <br>
# QB_Jameis_Winston = 1.0 <br>
# RB_Alvin_Kamara = 1.0 <br>
# RB_Jaylen_Samuels = 1.0 <br>
# TE_Eric_Ebron = 1.0 <br>
# WR_Chris_Godwin = 1.0 <br>
# WR_Sterling_Shepard = 1.0 <br>
#
# **---------------------------------------**
#
# Constraints:
# 3700* 1.0 + 4500* 1.0 + 4000* 1.0 + 7700* 1.0 + 8300* 1.0 + 4600* 1.0 + 6400* 1.0 + 5600* 1.0 + 5200* 1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 7.8* 1.0 + 10.0* 1.0 + 8.21* 1.0 + 21.2* 1.0 + 19.02* 1.0 + 12.14* 1.0 + 12.11* 1.0 + 11.03* 1.0 + 10.6* 1.0 = 112.11

# %% [markdown]
# ### Week 15
#
# Variables:
#
# DST_Chicago_Bears = 1.0 <br>
# FLEX_Damien_Williams = 1.0<br>
# K_Greg_Zuerlein = 1.0<br>
# QB_Nick_Foles = 1.0<br>
# RB_Jaylen_Samuels = 1.0<br>
# RB_Justin_Jackson = 1.0<br>
# TE_Travis_Kelce = 1.0<br>
# WR_Amari_Cooper = 1.0<br>
# WR_Sterling_Shepard = 1.0<br>
#
# **---------------------------------------**
#
# Constraints:
# 3700* 1.0 + 5500* 1.0 + 5000* 1.0 + 6000* 1.0 + 5500* 1.0 + 4500* 1.0 + 7900* 1.0 + 6600* 1.0 + 5200* 1.0 = 49900.0
#
# **---------------------------------------**
#
# Score:
# 9.0* 1.0 + 11.57* 1.0 + 11.43* 1.0 + 16.53* 1.0 + 12.38* 1.0 + 13.67* 1.0 + 15.56* 1.0 + 14.23* 1.0 + 10.03* 1.0 = 114.4

# %% [markdown]
# ### Week 16
#
# Variables:
#
# DST_Philadelphia_Eagles = 1.0<br>
# FLEX_Elijah_McGuire = 1.0<br>
# K_Brandon_McManus = 1.0<br>
# QB_Nick_Foles = 1.0<br>
# RB_Ezekiel_Elliott = 1.0<br>
# RB_Jamaal_Williams = 1.0<br>
# TE_Eric_Ebron = 1.0<br>
# WR_Dante_Pettis = 1.0<br>
# WR_Sterling_Shepard = 1.0<br>
#
# **---------------------------------------**
#
# Constraints:
# 3200* 1.0 + 5700* 1.0 + 4000* 1.0 + 6000* 1.0 + 8800* 1.0 + 5800* 1.0 + 6100* 1.0 + 5400* 1.0 + 5000* 1.0 = 50000.0
#
# **---------------------------------------**
#
# Score:
# 7.1* 1.0 + 12.39* 1.0 + 8.14* 1.0 + 16.71* 1.0 + 20.99* 1.0 + 13.04* 1.0 + 10.87* 1.0 + 10.0* 1.0 + 9.18* 1.0 = 108.42000000000002

# %% [markdown]
# ### Week 17
#
# Variables:
#
# DST_New_York_Giants = 1.0 <br>
# FLEX_Dwayne_Washington = 1.0<br>
# K_Harrison_Butker = 1.0<br>
# QB_Patrick_Mahomes = 1.0<br>
# RB_Chris_Carson = 1.0<br>
# RB_Royce_Freeman = 1.0<br>
# TE_Eric_Ebron = 1.0<br>
# WR_Jordy_Nelson = 1.0<br>
# WR_Sterling_Shepard = 1.0<br>
#
# **---------------------------------------**
#
# Constraints:
# 3300* 1.0 + 4500* 1.0 + 5000* 1.0 + 9500* 1.0 + 6400* 1.0 + 4700* 1.0 + 5800* 1.0 + 5200* 1.0 + 5500* 1.0 = 49900.0
#
# **---------------------------------------**
#
# Score:
# 7.6* 1.0 + 9.34* 1.0 + 10.66* 1.0 + 23.7* 1.0 + 14.0* 1.0 + 10.15* 1.0 + 10.61* 1.0 + 10.19* 1.0 + 9.89* 1.0 = 106.14
